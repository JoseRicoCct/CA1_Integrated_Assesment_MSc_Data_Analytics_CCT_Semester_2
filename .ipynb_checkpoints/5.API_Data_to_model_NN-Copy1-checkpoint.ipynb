# %%
import keras
from keras import layers
from keras.datasets import imdb
from keras.preprocessing import sequence

# Configuration adjustments for faster training
max_features = 2000  # Number of words to consider as features
max_len = 250  # Further reduce the sequence length for faster processing
gru_units = 16  # Further reduce number of GRU units
embedding_dim = 32  # Reduce embedding dimensionality

# Load the IMDb data
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

# Preprocess the data
x_train = sequence.pad_sequences(x_train, maxlen=max_len)
x_test = sequence.pad_sequences(x_test, maxlen=max_len)

# Define the model with further adjustments
model = keras.models.Sequential()
model.add(layers.Embedding(max_features, embedding_dim, input_length=max_len))
model.add(layers.GRU(gru_units, dropout=0.1, recurrent_dropout=0.5))
model.add(layers.Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model with further adjustments
history = model.fit(x_train, y_train,
                    epochs=30,  # You may want to keep it to 10 or use early stopping
                    batch_size=256,  # Increased batch size for faster epochs
                    validation_split=0.2)
# Out:
# Epoch 1/30
# 79/79 [==============================] - 27s 315ms/step - loss: 0.6696 - accuracy: 0.6041 - val_loss: 0.5817 - val_accuracy: 0.6992
# Epoch 2/30
# 79/79 [==============================] - 28s 355ms/step - loss: 0.4599 - accuracy: 0.7928 - val_loss: 0.4762 - val_accuracy: 0.7920
# Epoch 3/30
# 79/79 [==============================] - 24s 310ms/step - loss: 0.3985 - accuracy: 0.8319 - val_loss: 0.3878 - val_accuracy: 0.8374
# Epoch 4/30
# 79/79 [==============================] - 24s 298ms/step - loss: 0.3670 - accuracy: 0.8504 - val_loss: 0.3729 - val_accuracy: 0.8486
# Epoch 5/30
# 79/79 [==============================] - 22s 283ms/step - loss: 0.3457 - accuracy: 0.8590 - val_loss: 0.3688 - val_accuracy: 0.8516
# Epoch 6/30
# 79/79 [==============================] - 23s 288ms/step - loss: 0.3352 - accuracy: 0.8645 - val_loss: 0.3617 - val_accuracy: 0.8566
# Epoch 7/30
# 79/79 [==============================] - 27s 345ms/step - loss: 0.3183 - accuracy: 0.8719 - val_loss: 0.3392 - val_accuracy: 0.8630
# Epoch 8/30
# 79/79 [==============================] - 27s 336ms/step - loss: 0.3071 - accuracy: 0.8759 - val_loss: 0.3594 - val_accuracy: 0.8594
# Epoch 9/30
# 79/79 [==============================] - 25s 315ms/step - loss: 0.2972 - accuracy: 0.8819 - val_loss: 0.3336 - val_accuracy: 0.8650
# Epoch 10/30
# 79/79 [==============================] - 24s 299ms/step - loss: 0.2885 - accuracy: 0.8864 - val_loss: 0.3298 - val_accuracy: 0.8696
# Epoch 11/30
# 79/79 [==============================] - 24s 300ms/step - loss: 0.2824 - accuracy: 0.8878 - val_loss: 0.3271 - val_accuracy: 0.8690
# Epoch 12/30
# 79/79 [==============================] - 25s 318ms/step - loss: 0.2696 - accuracy: 0.8948 - val_loss: 0.3276 - val_accuracy: 0.8698
# Epoch 13/30
# 79/79 [==============================] - 26s 331ms/step - loss: 0.2695 - accuracy: 0.8932 - val_loss: 0.3200 - val_accuracy: 0.8732
# Epoch 14/30
# 79/79 [==============================] - 26s 324ms/step - loss: 0.2615 - accuracy: 0.8987 - val_loss: 0.3226 - val_accuracy: 0.8736
# Epoch 15/30
# 79/79 [==============================] - 25s 316ms/step - loss: 0.2541 - accuracy: 0.9003 - val_loss: 0.3397 - val_accuracy: 0.8682
# Epoch 16/30
# 79/79 [==============================] - 26s 327ms/step - loss: 0.2517 - accuracy: 0.9015 - val_loss: 0.3158 - val_accuracy: 0.8720
# Epoch 17/30
# 79/79 [==============================] - 25s 315ms/step - loss: 0.2512 - accuracy: 0.9014 - val_loss: 0.3262 - val_accuracy: 0.8692
# Epoch 18/30
# 79/79 [==============================] - 24s 302ms/step - loss: 0.2441 - accuracy: 0.9049 - val_loss: 0.3204 - val_accuracy: 0.8724
# Epoch 19/30
# 79/79 [==============================] - 24s 305ms/step - loss: 0.2423 - accuracy: 0.9054 - val_loss: 0.3206 - val_accuracy: 0.8726
# Epoch 20/30
# 79/79 [==============================] - 22s 282ms/step - loss: 0.2351 - accuracy: 0.9093 - val_loss: 0.3268 - val_accuracy: 0.8706
# Epoch 21/30
# 79/79 [==============================] - 23s 287ms/step - loss: 0.2352 - accuracy: 0.9069 - val_loss: 0.3382 - val_accuracy: 0.8678
# Epoch 22/30
# 79/79 [==============================] - 23s 293ms/step - loss: 0.2272 - accuracy: 0.9146 - val_loss: 0.3201 - val_accuracy: 0.8710
# Epoch 23/30
# 79/79 [==============================] - 24s 299ms/step - loss: 0.2216 - accuracy: 0.9153 - val_loss: 0.3273 - val_accuracy: 0.8690
# Epoch 24/30
# 79/79 [==============================] - 24s 298ms/step - loss: 0.2203 - accuracy: 0.9151 - val_loss: 0.3400 - val_accuracy: 0.8678
# Epoch 25/30
# 79/79 [==============================] - 23s 293ms/step - loss: 0.2182 - accuracy: 0.9168 - val_loss: 0.3436 - val_accuracy: 0.8690
# Epoch 26/30
# 79/79 [==============================] - 24s 301ms/step - loss: 0.2166 - accuracy: 0.9173 - val_loss: 0.3227 - val_accuracy: 0.8716
# Epoch 27/30
# 79/79 [==============================] - 24s 298ms/step - loss: 0.2183 - accuracy: 0.9158 - val_loss: 0.3438 - val_accuracy: 0.8644
# Epoch 28/30
# 79/79 [==============================] - 22s 283ms/step - loss: 0.2087 - accuracy: 0.9204 - val_loss: 0.3312 - val_accuracy: 0.8706
# Epoch 29/30
# 79/79 [==============================] - 22s 283ms/step - loss: 0.2044 - accuracy: 0.9215 - val_loss: 0.3329 - val_accuracy: 0.8668
# Epoch 30/30
# 79/79 [==============================] - 22s 284ms/step - loss: 0.1991 - accuracy: 0.9247 - val_loss: 0.3429 - val_accuracy: 0.8708

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.datasets import imdb
from keras.preprocessing import sequence
from keras import layers
from keras.models import Sequential

# Converting history into a DataFrame
history_df = pd.DataFrame(history.history)

# Extracting epochs
epochs_range = np.array(range(1, len(history_df) + 1))

# Plot Training and Validation Accuracy
plt.figure(figsize=(14, 5))

# Plot training and validation accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs_range, history_df['accuracy'], label='Training Accuracy', color='blue')
plt.plot(epochs_range, history_df['val_accuracy'], label='Validation Accuracy', color='green')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, history_df['loss'], label='Training Loss', color='red')
plt.plot(epochs_range, history_df['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.suptitle("Model Training: Accuracy and Loss Over Epochs")
plt.tight_layout()
plt.show()

# %%
import keras
from keras import layers
from keras.datasets import imdb
from keras.preprocessing import sequence
from keras import regularizers

# Configuration adjustments for faster training
max_features = 2000  # Number of words to consider as features
max_len = 350  # Further reduce the sequence length for faster processing
gru_units = 16  # Further reduce number of GRU units
embedding_dim = 32  # Reduce embedding dimensionality

# Load the IMDb data
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

# Preprocess the data
x_train = sequence.pad_sequences(x_train, maxlen=max_len)
x_test = sequence.pad_sequences(x_test, maxlen=max_len)

# Define the model with further adjustments
model = keras.models.Sequential()
model.add(layers.Embedding(max_features, embedding_dim, input_length=max_len))
model.add(layers.GRU(gru_units, dropout=0.1, recurrent_dropout=0.5))
model.add(layers.Dense(1, activation='sigmoid', 
                       kernel_regularizer=regularizers.l2(0.001))) # L2 Regularization

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model with further adjustments
history = model.fit(x_train, y_train,
                    epochs=30,
                    batch_size=256,
                    validation_split=0.2)
# Out:
# Epoch 1/30
# 79/79 [==============================] - 49s 595ms/step - loss: 0.6831 - accuracy: 0.5907 - val_loss: 0.6467 - val_accuracy: 0.6564
# Epoch 2/30
# 79/79 [==============================] - 47s 592ms/step - loss: 0.5200 - accuracy: 0.7576 - val_loss: 0.4789 - val_accuracy: 0.7966
# Epoch 3/30
# 79/79 [==============================] - 48s 609ms/step - loss: 0.4235 - accuracy: 0.8179 - val_loss: 0.3946 - val_accuracy: 0.8360
# Epoch 4/30
# 79/79 [==============================] - 48s 604ms/step - loss: 0.4005 - accuracy: 0.8326 - val_loss: 0.3875 - val_accuracy: 0.8314
# Epoch 5/30
# 79/79 [==============================] - 44s 553ms/step - loss: 0.3750 - accuracy: 0.8497 - val_loss: 0.3909 - val_accuracy: 0.8446
# Epoch 6/30
# 79/79 [==============================] - 48s 610ms/step - loss: 0.3736 - accuracy: 0.8472 - val_loss: 0.3848 - val_accuracy: 0.8424
# Epoch 7/30
# 79/79 [==============================] - 45s 567ms/step - loss: 0.3484 - accuracy: 0.8619 - val_loss: 0.3698 - val_accuracy: 0.8508
# Epoch 8/30
# 79/79 [==============================] - 53s 673ms/step - loss: 0.3388 - accuracy: 0.8663 - val_loss: 0.3912 - val_accuracy: 0.8458
# Epoch 9/30
# 79/79 [==============================] - 51s 640ms/step - loss: 0.3304 - accuracy: 0.8694 - val_loss: 0.3776 - val_accuracy: 0.8508
# Epoch 10/30
# 79/79 [==============================] - 50s 634ms/step - loss: 0.3300 - accuracy: 0.8700 - val_loss: 0.3608 - val_accuracy: 0.8560
# Epoch 11/30
# 79/79 [==============================] - 40s 501ms/step - loss: 0.3055 - accuracy: 0.8832 - val_loss: 0.3679 - val_accuracy: 0.8572
# Epoch 12/30
# 79/79 [==============================] - 38s 482ms/step - loss: 0.2990 - accuracy: 0.8842 - val_loss: 0.3392 - val_accuracy: 0.8646
# Epoch 13/30
# 79/79 [==============================] - 35s 448ms/step - loss: 0.2887 - accuracy: 0.8900 - val_loss: 0.3574 - val_accuracy: 0.8646
# Epoch 14/30
# 79/79 [==============================] - 55s 702ms/step - loss: 0.2877 - accuracy: 0.8907 - val_loss: 0.3360 - val_accuracy: 0.8664
# Epoch 15/30
# 79/79 [==============================] - 49s 621ms/step - loss: 0.2742 - accuracy: 0.8960 - val_loss: 0.3248 - val_accuracy: 0.8714
# Epoch 16/30
# 79/79 [==============================] - 77s 976ms/step - loss: 0.2682 - accuracy: 0.8977 - val_loss: 0.3400 - val_accuracy: 0.8670
# Epoch 17/30
# 79/79 [==============================] - 76s 965ms/step - loss: 0.2626 - accuracy: 0.8992 - val_loss: 0.3249 - val_accuracy: 0.8738
# Epoch 18/30
# 79/79 [==============================] - 42s 524ms/step - loss: 0.2599 - accuracy: 0.9039 - val_loss: 0.3202 - val_accuracy: 0.8750
# Epoch 19/30
# 79/79 [==============================] - 35s 445ms/step - loss: 0.2524 - accuracy: 0.9050 - val_loss: 0.3286 - val_accuracy: 0.8718
# Epoch 20/30
# 79/79 [==============================] - 37s 465ms/step - loss: 0.2521 - accuracy: 0.9036 - val_loss: 0.3268 - val_accuracy: 0.8730
# Epoch 21/30
# 79/79 [==============================] - 36s 455ms/step - loss: 0.2485 - accuracy: 0.9064 - val_loss: 0.3192 - val_accuracy: 0.8760
# Epoch 22/30
# 79/79 [==============================] - 36s 461ms/step - loss: 0.2475 - accuracy: 0.9069 - val_loss: 0.3263 - val_accuracy: 0.8752
# Epoch 23/30
# 79/79 [==============================] - 36s 461ms/step - loss: 0.2366 - accuracy: 0.9132 - val_loss: 0.3263 - val_accuracy: 0.8708
# Epoch 24/30
# 79/79 [==============================] - 36s 456ms/step - loss: 0.2357 - accuracy: 0.9132 - val_loss: 0.3244 - val_accuracy: 0.8744
# Epoch 25/30
# 79/79 [==============================] - 37s 470ms/step - loss: 0.2280 - accuracy: 0.9162 - val_loss: 0.3345 - val_accuracy: 0.8700
# Epoch 26/30
# 79/79 [==============================] - 68s 868ms/step - loss: 0.2254 - accuracy: 0.9167 - val_loss: 0.3354 - val_accuracy: 0.8724
# Epoch 27/30
# 79/79 [==============================] - 41s 512ms/step - loss: 0.2218 - accuracy: 0.9203 - val_loss: 0.3394 - val_accuracy: 0.8694
# Epoch 28/30
# 79/79 [==============================] - 37s 468ms/step - loss: 0.2205 - accuracy: 0.9198 - val_loss: 0.3362 - val_accuracy: 0.8714
# Epoch 29/30
# 79/79 [==============================] - 70s 889ms/step - loss: 0.2194 - accuracy: 0.9200 - val_loss: 0.3367 - val_accuracy: 0.8702
# Epoch 30/30
# 79/79 [==============================] - 79s 995ms/step - loss: 0.2161 - accuracy: 0.9236 - val_loss: 0.3315 - val_accuracy: 0.8702

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.datasets import imdb
from keras.preprocessing import sequence
from keras import layers
from keras.models import Sequential

# Converting history into a DataFrame
history_df = pd.DataFrame(history.history)

# Extracting epochs
epochs_range = np.array(range(1, len(history_df) + 1))

# Plot Training and Validation Accuracy
plt.figure(figsize=(14, 5))

# Plot training and validation accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs_range, history_df['accuracy'], label='Training Accuracy', color='blue')
plt.plot(epochs_range, history_df['val_accuracy'], label='Validation Accuracy', color='green')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, history_df['loss'], label='Training Loss', color='red')
plt.plot(epochs_range, history_df['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.suptitle("Model Training: Accuracy and Loss Over Epochs")
plt.tight_layout()
plt.show()

# %%
import keras
from keras import layers
from keras.datasets import imdb
from keras.preprocessing import sequence

# Configuration adjustments for faster training
max_features = 2000  # Number of words to consider as features
max_len = 500  # Further reduce the sequence length for faster processing
gru_units = 16  # Further reduce number of GRU units
embedding_dim = 32  # Reduce embedding dimensionality

# Load the IMDb data
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

# Preprocess the data
x_train = sequence.pad_sequences(x_train, maxlen=max_len)
x_test = sequence.pad_sequences(x_test, maxlen=max_len)

# Define the model with further adjustments
model = keras.models.Sequential()
model.add(layers.Embedding(max_features, embedding_dim, input_length=max_len))
model.add(layers.GRU(gru_units, dropout=0.1, recurrent_dropout=0.5))
model.add(layers.Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model with further adjustments
history = model.fit(x_train, y_train,
                    epochs=30,  # You may want to keep it to 10 or use early stopping
                    batch_size=256,  # Increased batch size for faster epochs
                    validation_split=0.2)
# Out:
# Epoch 1/30
# 11/79 [===>..........................] - ETA: 1:00 - loss: 0.6921 - accuracy: 0.5146
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Train the model with further adjustments
# ----> 2 history = model.fit(x_train, y_train,
#       3                     epochs=30,  # You may want to keep it to 10 or use early stopping
#       4                     batch_size=256,  # Increased batch size for faster epochs
#       5                     validation_split=0.2)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\keras\src\engine\training.py:1783, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1775 with tf.profiler.experimental.Trace(
#    1776     "train",
#    1777     epoch_num=epoch,
#    (...)
#    1780     _r=1,
#    1781 ):
#    1782     callbacks.on_train_batch_begin(step)
# -> 1783     tmp_logs = self.train_function(iterator)
#    1784     if data_handler.should_sync:
#    1785         context.async_wait()
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:831, in Function.__call__(self, *args, **kwds)
#     828 compiler = "xla" if self._jit_compile else "nonXla"
#     830 with OptionalXlaContext(self._jit_compile):
# --> 831   result = self._call(*args, **kwds)
#     833 new_tracing_count = self.experimental_get_tracing_count()
#     834 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:867, in Function._call(self, *args, **kwds)
#     864   self._lock.release()
#     865   # In this case we have created variables on the first call, so we run the
#     866   # defunned version which is guaranteed to never create variables.
# --> 867   return tracing_compilation.call_function(
#     868       args, kwds, self._no_variable_creation_config
#     869   )
#     870 elif self._variable_creation_config is not None:
#     871   # Release the lock early so that multiple threads can perform the call
#     872   # in parallel.
#     873   self._lock.release()
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1264, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1260 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1261 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1262     and executing_eagerly):
#    1263   # No tape is watching; skip to running the function.
# -> 1264   return self._inference_function.flat_call(args)
#    1265 forward_backward = self._select_forward_and_backward_functions(
#    1266     args,
#    1267     possible_gradient_type,
#    1268     executing_eagerly)
#    1269 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:217, in AtomicFunction.flat_call(self, args)
#     215 def flat_call(self, args: Sequence[core.Tensor]) -> Any:
#     216   """Calls with tensor inputs and returns the structured output."""
# --> 217   flat_outputs = self(*args)
#     218   return self.function_type.pack_output(flat_outputs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:252, in AtomicFunction.__call__(self, *args)
#     250 with record.stop_recording():
#     251   if self._bound_context.executing_eagerly():
# --> 252     outputs = self._bound_context.call_function(
#     253         self.name,
#     254         list(args),
#     255         len(self.function_type.flat_outputs),
#     256     )
#     257   else:
#     258     outputs = make_call_op_in_graph(
#     259         self,
#     260         list(args),
#     261         self._bound_context.function_call_options.as_attrs(),
#     262     )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\context.py:1479, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1477 cancellation_context = cancellation.context()
#    1478 if cancellation_context is None:
# -> 1479   outputs = execute.execute(
#    1480       name.decode("utf-8"),
#    1481       num_outputs=num_outputs,
#    1482       inputs=tensor_inputs,
#    1483       attrs=attrs,
#    1484       ctx=self,
#    1485   )
#    1486 else:
#    1487   outputs = execute.execute_with_cancellation(
#    1488       name.decode("utf-8"),
#    1489       num_outputs=num_outputs,
#    (...)
#    1493       cancellation_manager=cancellation_context,
#    1494   )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:60, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53   # Convert any objects of type core_types.Tensor to Tensor.
#      54   inputs = [
#      55       tensor_conversion_registry.convert(t)
#      56       if isinstance(t, core_types.Tensor)
#      57       else t
#      58       for t in inputs
#      59   ]
# ---> 60   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                       inputs, attrs, num_outputs)
#      62 except core._NotOkStatusException as e:
#      63   if name is not None:
#
# KeyboardInterrupt:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.datasets import imdb
from keras.preprocessing import sequence
from keras import layers
from keras.models import Sequential

# Converting history into a DataFrame
history_df = pd.DataFrame(history.history)

# Extracting epochs
epochs_range = np.array(range(1, len(history_df) + 1))

# Plot Training and Validation Accuracy
plt.figure(figsize=(14, 5))

# Plot training and validation accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs_range, history_df['accuracy'], label='Training Accuracy', color='blue')
plt.plot(epochs_range, history_df['val_accuracy'], label='Validation Accuracy', color='green')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, history_df['loss'], label='Training Loss', color='red')
plt.plot(epochs_range, history_df['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.suptitle("Model Training: Accuracy and Loss Over Epochs")
plt.tight_layout()
plt.show()
