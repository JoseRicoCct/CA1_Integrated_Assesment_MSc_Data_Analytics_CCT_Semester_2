# %%
import pandas as pd
from datetime import datetime
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt


# Replace 'file_path' with the path to your CSV file
file_path = "C:/Users/jose/Downloads/people.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
df.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  4defE49671cF860     Sydney   Shannon    Male
# 1      2  F89B87bCf8f210b     Regina       Lin    Male
# 2      3  Cad6052BDd5DEaf     Pamela     Blake  Female
# 3      4  e83E46f80f629CD       Dave   Hoffman  Female
# 4      5  60AAc4DcaBcE3b6        Ian    Campos  Female
#
#                      Email                   Phone Date of birth  \
# 0        tvang@example.net       574-440-1423x9799    2020-07-09
# 1      helen14@example.net  001-273-664-2268x90121    1909-06-20
# 2      brent05@example.org      927-880-5785x85266    1964-08-19
# 3   munozcraig@example.org    001-147-429-8340x608    2009-02-19
# 4  brownevelyn@example.net            166-126-4390    1997-10-02
#
#                           Job Title
# 0                  Technical brewer
# 1          Teacher, adult education
# 2  Armed forces operational officer
# 3                       Ship broker
# 4                     Media planner

# %%
# Assuming 'Date of birth' is in YYYY-MM-DD format
df['Date of birth'] = pd.to_datetime(df['Date of birth'])
df['Age'] = df['Date of birth'].apply(lambda x: datetime.now().year - x.year)

# Creating a new column 'Job_Title_Count' containing the total count of each Job Title
df['Job_Title_Count'] = df.groupby('Job Title')['Job Title'].transform('count')

# %%
# Renaming the column 'Job Title' to 'Job_Title'
df = df.rename(columns={'Job Title': 'Job_Title'})
df = df.rename(columns={'Sex': 'Gender'})

# %%
# Encoding "Sex" as binary values
encoder = LabelEncoder()
df['Gender'] = encoder.fit_transform(df['Gender'])  # Male will be 1, Female will be 0

# %%
# Selecting only needed columns

# Dropping columns except 'Sex', 'Date of birth', and 'Job Title'
df = df[['Gender', 'Job_Title','Age']]

# Renaming the column 'Job Title' to 'Job_Title'
df = df.rename(columns={'Job Title': 'Job_Title'})

df = df.reset_index(drop=True).rename_axis(None, axis=1)

df
# Out:
#          Gender                         Job_Title  Age
# 0             1                  Technical brewer    4
# 1             1          Teacher, adult education  115
# 2             0  Armed forces operational officer   60
# 3             0                       Ship broker   15
# 4             0                     Media planner   27
# ...         ...                               ...  ...
# 1999995       1        Research scientist (maths)  111
# 1999996       0               Marketing executive   47
# 1999997       1                      Photographer   64
# 1999998       0              Chartered accountant  113
# 1999999       0                        Printmaker   63
#
# [2000000 rows x 3 columns]

# %%
# Creating df1 and df2 to optimise NN
df1 = df.copy()
df2= df.copy()

# %%
X = df.iloc[:,1:] # selecting all columns except Gender| Dependent variables
y = df.iloc[:,0] # selecting Gender as our target variable | Independent variable

# %%
# Encoding "Sex" as binary values
encoder = LabelEncoder()
X['Job_Title'] = encoder.fit_transform(X['Job_Title'])  # Male will be 1, Female will be 0

# %%
X
# Out:
#          Job_Title  Age
# 0              592    4
# 1              584  115
# 2               45   60
# 3              544   15
# 4              369   27
# ...            ...  ...
# 1999995        508  111
# 1999996        365   47
# 1999997        434   64
# 1999998         86  113
# 1999999        450   63
#
# [2000000 rows x 2 columns]

# %%
y
# Out:
# 0          1
# 1          1
# 2          0
# 3          0
# 4          0
#           ..
# 1999995    1
# 1999996    0
# 1999997    1
# 1999998    0
# 1999999    0
# Name: Gender, Length: 2000000, dtype: int32

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
model = Sequential()
model.add(Dense(10,input_dim=2,activation='relu')) # First layer
model.add(Dense(10,activation='relu')) # Second layer
model.add(Dense(1,activation='sigmoid'))

# %%
# Compile the model
model.compile(loss="binary_crossentropy",optimizer='adam',metrics=['accuracy'])

# %%
# Train the model
history = model.fit(X, y, epochs=150, batch_size=512, verbose=2)
# Out:
# Epoch 1/150
# 3907/3907 - 5s - loss: 0.6933 - accuracy: 0.5003 - 5s/epoch - 1ms/step
# Epoch 2/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.5000 - 4s/epoch - 1ms/step
# Epoch 3/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.5001 - 4s/epoch - 1ms/step
# Epoch 4/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.4998 - 4s/epoch - 1ms/step
# Epoch 5/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.4999 - 4s/epoch - 1ms/step
# Epoch 6/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.5007 - 4s/epoch - 1ms/step
# Epoch 7/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5009 - 4s/epoch - 1ms/step
# Epoch 8/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5002 - 4s/epoch - 1ms/step
# Epoch 9/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5000 - 4s/epoch - 1ms/step
# Epoch 10/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5002 - 4s/epoch - 1ms/step
# Epoch 11/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.4998 - 4s/epoch - 1ms/step
# Epoch 12/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5005 - 4s/epoch - 1ms/step
# Epoch 13/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5001 - 4s/epoch - 1ms/step
# Epoch 14/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4999 - 4s/epoch - 1ms/step
# Epoch 15/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.5002 - 4s/epoch - 1ms/step
# Epoch 16/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4990 - 4s/epoch - 1ms/step
# Epoch 17/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4999 - 4s/epoch - 1ms/step
# Epoch 18/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.4998 - 4s/epoch - 1ms/step
# Epoch 19/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.4994 - 4s/epoch - 1ms/step
# Epoch 20/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4997 - 4s/epoch - 1ms/step
# Epoch 21/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5001 - 4s/epoch - 1ms/step
# Epoch 22/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4996 - 4s/epoch - 1ms/step
# Epoch 23/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4989 - 4s/epoch - 1ms/step
# Epoch 24/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4992 - 4s/epoch - 1ms/step
# Epoch 25/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.4996 - 4s/epoch - 1ms/step
# Epoch 26/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4989 - 4s/epoch - 1ms/step
# Epoch 27/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5001 - 4s/epoch - 1ms/step
# Epoch 28/150
# 3907/3907 - 5s - loss: 0.6931 - accuracy: 0.5002 - 5s/epoch - 1ms/step
# Epoch 29/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5001 - 4s/epoch - 1ms/step
# Epoch 30/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4997 - 4s/epoch - 1ms/step
# Epoch 31/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5001 - 4s/epoch - 1ms/step
# Epoch 32/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5010 - 4s/epoch - 1ms/step
# Epoch 33/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4991 - 4s/epoch - 1ms/step
# Epoch 34/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5002 - 4s/epoch - 1ms/step
# Epoch 35/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5004 - 4s/epoch - 1ms/step
# Epoch 36/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5001 - 4s/epoch - 1ms/step
# Epoch 37/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4998 - 4s/epoch - 1ms/step
# Epoch 38/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.4999 - 4s/epoch - 1ms/step
# Epoch 39/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.4999 - 4s/epoch - 1ms/step
# Epoch 40/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5000 - 4s/epoch - 1ms/step
# Epoch 41/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5003 - 4s/epoch - 1ms/step
# Epoch 42/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4997 - 4s/epoch - 1ms/step
# Epoch 43/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5002 - 4s/epoch - 1ms/step
# Epoch 44/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4996 - 4s/epoch - 1ms/step
# Epoch 45/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5001 - 4s/epoch - 1ms/step
# Epoch 46/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4998 - 4s/epoch - 1ms/step
# Epoch 47/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4998 - 4s/epoch - 1ms/step
# Epoch 48/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5005 - 4s/epoch - 1ms/step
# Epoch 49/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.5000 - 4s/epoch - 1ms/step
# Epoch 50/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5002 - 4s/epoch - 1ms/step
# Epoch 51/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5002 - 4s/epoch - 1ms/step
# Epoch 52/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5001 - 4s/epoch - 1ms/step
# Epoch 53/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4997 - 4s/epoch - 1ms/step
# Epoch 54/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5003 - 4s/epoch - 1ms/step
# Epoch 55/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5003 - 4s/epoch - 1ms/step
# Epoch 56/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4996 - 4s/epoch - 1ms/step
# Epoch 57/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4997 - 4s/epoch - 1ms/step
# Epoch 58/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4995 - 4s/epoch - 1ms/step
# Epoch 59/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5003 - 4s/epoch - 1ms/step
# Epoch 60/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4996 - 4s/epoch - 992us/step
# Epoch 61/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5007 - 4s/epoch - 993us/step
# Epoch 62/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4999 - 4s/epoch - 988us/step
# Epoch 63/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5006 - 4s/epoch - 996us/step
# Epoch 64/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4996 - 4s/epoch - 983us/step
# Epoch 65/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5006 - 4s/epoch - 1ms/step
# Epoch 66/150
# 3907/3907 - 5s - loss: 0.6931 - accuracy: 0.4995 - 5s/epoch - 1ms/step
# Epoch 67/150
# 3907/3907 - 5s - loss: 0.6931 - accuracy: 0.4998 - 5s/epoch - 1ms/step
# Epoch 68/150
# 3907/3907 - 5s - loss: 0.6932 - accuracy: 0.4995 - 5s/epoch - 1ms/step
# Epoch 69/150
# 3907/3907 - 5s - loss: 0.6931 - accuracy: 0.4997 - 5s/epoch - 1ms/step
# Epoch 70/150
# 3907/3907 - 5s - loss: 0.6931 - accuracy: 0.4998 - 5s/epoch - 1ms/step
# Epoch 71/150
# 3907/3907 - 5s - loss: 0.6931 - accuracy: 0.5000 - 5s/epoch - 1ms/step
# Epoch 72/150
# 3907/3907 - 7s - loss: 0.6932 - accuracy: 0.4997 - 7s/epoch - 2ms/step
# Epoch 73/150
# 3907/3907 - 6s - loss: 0.6931 - accuracy: 0.4995 - 6s/epoch - 2ms/step
# Epoch 74/150
# 3907/3907 - 6s - loss: 0.6932 - accuracy: 0.4995 - 6s/epoch - 2ms/step
# Epoch 75/150
# 3907/3907 - 6s - loss: 0.6931 - accuracy: 0.5001 - 6s/epoch - 2ms/step
# Epoch 76/150
# 3907/3907 - 7s - loss: 0.6931 - accuracy: 0.5005 - 7s/epoch - 2ms/step
# Epoch 77/150
# 3907/3907 - 7s - loss: 0.6931 - accuracy: 0.5002 - 7s/epoch - 2ms/step
# Epoch 78/150
# 3907/3907 - 7s - loss: 0.6931 - accuracy: 0.5004 - 7s/epoch - 2ms/step
# Epoch 79/150
# 3907/3907 - 7s - loss: 0.6931 - accuracy: 0.4998 - 7s/epoch - 2ms/step
# Epoch 80/150
# 3907/3907 - 7s - loss: 0.6931 - accuracy: 0.4999 - 7s/epoch - 2ms/step
# Epoch 81/150
# 3907/3907 - 7s - loss: 0.6931 - accuracy: 0.5003 - 7s/epoch - 2ms/step
# Epoch 82/150
# 3907/3907 - 6s - loss: 0.6931 - accuracy: 0.4998 - 6s/epoch - 1ms/step
# Epoch 83/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5002 - 4s/epoch - 1ms/step
# Epoch 84/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5002 - 4s/epoch - 1ms/step
# Epoch 85/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5007 - 4s/epoch - 1ms/step
# Epoch 86/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4998 - 4s/epoch - 931us/step
# Epoch 87/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5008 - 4s/epoch - 923us/step
# Epoch 88/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4995 - 4s/epoch - 913us/step
# Epoch 89/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5002 - 4s/epoch - 907us/step
# Epoch 90/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5000 - 4s/epoch - 941us/step
# Epoch 91/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4999 - 4s/epoch - 957us/step
# Epoch 92/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4999 - 4s/epoch - 932us/step
# Epoch 93/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4998 - 4s/epoch - 926us/step
# Epoch 94/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4996 - 4s/epoch - 929us/step
# Epoch 95/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4998 - 4s/epoch - 902us/step
# Epoch 96/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.4998 - 4s/epoch - 915us/step
# Epoch 97/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4998 - 4s/epoch - 909us/step
# Epoch 98/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4997 - 4s/epoch - 910us/step
# Epoch 99/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5000 - 4s/epoch - 911us/step
# Epoch 100/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5000 - 4s/epoch - 911us/step
# Epoch 101/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4999 - 4s/epoch - 943us/step
# Epoch 102/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4997 - 4s/epoch - 911us/step
# Epoch 103/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5006 - 4s/epoch - 905us/step
# Epoch 104/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5002 - 4s/epoch - 923us/step
# Epoch 105/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4998 - 4s/epoch - 969us/step
# Epoch 106/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4998 - 4s/epoch - 1ms/step
# Epoch 107/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5002 - 4s/epoch - 927us/step
# Epoch 108/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5003 - 4s/epoch - 923us/step
# Epoch 109/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5005 - 4s/epoch - 917us/step
# Epoch 110/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.4995 - 4s/epoch - 925us/step
# Epoch 111/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4998 - 4s/epoch - 941us/step
# Epoch 112/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5002 - 4s/epoch - 1ms/step
# Epoch 113/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5002 - 4s/epoch - 990us/step
# Epoch 114/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5003 - 4s/epoch - 909us/step
# Epoch 115/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5000 - 4s/epoch - 914us/step
# Epoch 116/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5000 - 4s/epoch - 913us/step
# Epoch 117/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.5004 - 4s/epoch - 919us/step
# Epoch 118/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5004 - 4s/epoch - 956us/step
# Epoch 119/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5000 - 4s/epoch - 936us/step
# Epoch 120/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4999 - 4s/epoch - 911us/step
# Epoch 121/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5000 - 4s/epoch - 914us/step
# Epoch 122/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.4993 - 4s/epoch - 916us/step
# Epoch 123/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4990 - 4s/epoch - 916us/step
# Epoch 124/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5002 - 4s/epoch - 909us/step
# Epoch 125/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5000 - 4s/epoch - 907us/step
# Epoch 126/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5000 - 4s/epoch - 905us/step
# Epoch 127/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.4994 - 4s/epoch - 911us/step
# Epoch 128/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5002 - 4s/epoch - 918us/step
# Epoch 129/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5000 - 4s/epoch - 923us/step
# Epoch 130/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5001 - 4s/epoch - 933us/step
# Epoch 131/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5000 - 4s/epoch - 928us/step
# Epoch 132/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5003 - 4s/epoch - 944us/step
# Epoch 133/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5002 - 4s/epoch - 939us/step
# Epoch 134/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5003 - 4s/epoch - 954us/step
# Epoch 135/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4993 - 4s/epoch - 924us/step
# Epoch 136/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4998 - 4s/epoch - 939us/step
# Epoch 137/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4998 - 4s/epoch - 919us/step
# Epoch 138/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5004 - 4s/epoch - 907us/step
# Epoch 139/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5001 - 4s/epoch - 919us/step
# Epoch 140/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4999 - 4s/epoch - 927us/step
# Epoch 141/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4998 - 4s/epoch - 923us/step
# Epoch 142/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5000 - 4s/epoch - 931us/step
# Epoch 143/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5007 - 4s/epoch - 931us/step
# Epoch 144/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5002 - 4s/epoch - 957us/step
# Epoch 145/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.4993 - 4s/epoch - 1ms/step
# Epoch 146/150
# 3907/3907 - 4s - loss: 0.6932 - accuracy: 0.5001 - 4s/epoch - 982us/step
# Epoch 147/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5000 - 4s/epoch - 924us/step
# Epoch 148/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5003 - 4s/epoch - 931us/step
# Epoch 149/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5001 - 4s/epoch - 910us/step
# Epoch 150/150
# 3907/3907 - 4s - loss: 0.6931 - accuracy: 0.5000 - 4s/epoch - 911us/step

# %%
# Convert history.history dict to a pandas DataFrame
history_df = pd.DataFrame(history.history)

# %%
# Extracting epochs
epochs_range = range(1, len(history_df) + 1)

# Plotting Training Accuracy
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, history_df['accuracy'], label='Training Accuracy', color='blue')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim(.4, 1)  # Set the y-axis limits for accuracy
plt.legend()

plt.suptitle("Model Training 1: Accuracy and Loss Over Epochs")

# Plotting Training Loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, history_df['loss'], label='Training Loss', color='red')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim(0, 0.8) # Set the y-axis limits for loss
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## The NN is clearly not performing well. Let's treat each job as a feature and transpose them into columns, filling each column with the Age.

# %%
df1
# Out:
#          Gender                         Job_Title  Age
# 0             1                  Technical brewer    4
# 1             1          Teacher, adult education  115
# 2             0  Armed forces operational officer   60
# 3             0                       Ship broker   15
# 4             0                     Media planner   27
# ...         ...                               ...  ...
# 1999995       1        Research scientist (maths)  111
# 1999996       0               Marketing executive   47
# 1999997       1                      Photographer   64
# 1999998       0              Chartered accountant  113
# 1999999       0                        Printmaker   63
#
# [2000000 rows x 3 columns]

# %%
# Add a unique identifier for each row within each group of 'Sex' and 'Job_Title'
df1['unique_id'] = df1.groupby(['Gender', 'Job_Title']).cumcount()

# Pivot the table, using 'Sex' and 'unique_id' as the index
df1 = df1.pivot_table(index=['Gender', 'unique_id'], columns='Job_Title', values='Age').reset_index()
df1  = df1.rename_axis(None, axis=1) # Index with no name as it should be

# Drop the 'unique_id' column as it's no longer needed, keeping 'Sex'
df1.drop('unique_id', axis=1, inplace=True)

# Display the result
df1
# Out:
#       Gender  Academic librarian  Accommodation manager  \
# 0          0                 3.0                    8.0
# 1          0                74.0                   35.0
# 2          0               114.0                   86.0
# 3          0                25.0                   32.0
# 4          0                53.0                   16.0
# ...      ...                 ...                    ...
# 3384       1                 NaN                    NaN
# 3385       1                 NaN                    NaN
# 3386       1                 NaN                    NaN
# 3387       1                 NaN                    NaN
# 3388       1                 NaN                    NaN
#
#       Accountant, chartered  Accountant, chartered certified  \
# 0                      54.0                             40.0
# 1                      40.0                             67.0
# 2                      22.0                            102.0
# 3                      37.0                             44.0
# 4                      60.0                             27.0
# ...                     ...                              ...
# 3384                    NaN                              NaN
# 3385                    NaN                              NaN
# 3386                    NaN                              NaN
# 3387                    NaN                              NaN
# 3388                    NaN                              NaN
#
#       Accountant, chartered management  Accountant, chartered public finance  \
# 0                                 41.0                                  35.0
# 1                                 74.0                                  55.0
# 2                                 86.0                                  99.0
# 3                                 97.0                                  92.0
# 4                                 57.0                                  60.0
# ...                                ...                                   ...
# 3384                               NaN                                   NaN
# 3385                               NaN                                   NaN
# 3386                               NaN                                   NaN
# 3387                               NaN                                   NaN
# 3388                               NaN                                   NaN
#
#       Accounting technician  Actor  Actuary  ...  Volunteer coordinator  \
# 0                     100.0    5.0     77.0  ...                   17.0
# 1                      60.0    6.0     34.0  ...                   19.0
# 2                      95.0  118.0     15.0  ...                  118.0
# 3                     110.0   34.0      7.0  ...                   15.0
# 4                      77.0   70.0     40.0  ...                   65.0
# ...                     ...    ...      ...  ...                    ...
# 3384                    NaN    NaN      NaN  ...                    NaN
# 3385                    NaN    NaN      NaN  ...                    NaN
# 3386                    NaN    NaN      NaN  ...                    NaN
# 3387                    NaN    NaN      NaN  ...                    NaN
# 3388                    NaN    NaN      NaN  ...                    NaN
#
#       Warden/ranger  Warehouse manager  Waste management officer  \
# 0              21.0                4.0                      44.0
# 1              96.0               74.0                      52.0
# 2              23.0               52.0                      42.0
# 3              45.0               20.0                      44.0
# 4              21.0              112.0                      64.0
# ...             ...                ...                       ...
# 3384            NaN                NaN                       NaN
# 3385            NaN                NaN                       NaN
# 3386            NaN                NaN                       NaN
# 3387            NaN                NaN                       NaN
# 3388            NaN                NaN                       NaN
#
#       Water engineer  Water quality scientist  Web designer  \
# 0               96.0                     78.0         112.0
# 1               59.0                    114.0         100.0
# 2              110.0                     45.0           5.0
# 3               84.0                     90.0          31.0
# 4               94.0                     56.0          83.0
# ...              ...                      ...           ...
# 3384             NaN                      NaN           NaN
# 3385             NaN                      NaN           NaN
# 3386             NaN                      NaN           NaN
# 3387             NaN                      NaN           NaN
# 3388             NaN                      NaN           NaN
#
#       Wellsite geologist  Writer  Youth worker
# 0                    3.0    78.0           6.0
# 1                   35.0    87.0          76.0
# 2                   86.0    15.0          50.0
# 3                   54.0    63.0           3.0
# 4                   94.0   104.0          32.0
# ...                  ...     ...           ...
# 3384                 NaN     NaN           NaN
# 3385                 NaN     NaN           NaN
# 3386                 NaN     NaN           NaN
# 3387                 NaN     NaN           NaN
# 3388                 NaN     NaN           NaN
#
# [3389 rows x 640 columns]

# %%
df1 = df1.dropna()

# %%
df1
# Out:
#       Gender  Academic librarian  Accommodation manager  \
# 0          0                 3.0                    8.0
# 1          0                74.0                   35.0
# 2          0               114.0                   86.0
# 3          0                25.0                   32.0
# 4          0                53.0                   16.0
# ...      ...                 ...                    ...
# 3133       1                23.0                   38.0
# 3134       1                23.0                   78.0
# 3135       1                18.0                   61.0
# 3136       1                60.0                   59.0
# 3137       1               102.0                   53.0
#
#       Accountant, chartered  Accountant, chartered certified  \
# 0                      54.0                             40.0
# 1                      40.0                             67.0
# 2                      22.0                            102.0
# 3                      37.0                             44.0
# 4                      60.0                             27.0
# ...                     ...                              ...
# 3133                   86.0                             36.0
# 3134                   43.0                             65.0
# 3135                   93.0                             33.0
# 3136                   75.0                             55.0
# 3137                   95.0                            101.0
#
#       Accountant, chartered management  Accountant, chartered public finance  \
# 0                                 41.0                                  35.0
# 1                                 74.0                                  55.0
# 2                                 86.0                                  99.0
# 3                                 97.0                                  92.0
# 4                                 57.0                                  60.0
# ...                                ...                                   ...
# 3133                               6.0                                  61.0
# 3134                             109.0                                  33.0
# 3135                              23.0                                   6.0
# 3136                               3.0                                  87.0
# 3137                              66.0                                  67.0
#
#       Accounting technician  Actor  Actuary  ...  Volunteer coordinator  \
# 0                     100.0    5.0     77.0  ...                   17.0
# 1                      60.0    6.0     34.0  ...                   19.0
# 2                      95.0  118.0     15.0  ...                  118.0
# 3                     110.0   34.0      7.0  ...                   15.0
# 4                      77.0   70.0     40.0  ...                   65.0
# ...                     ...    ...      ...  ...                    ...
# 3133                   53.0   70.0     80.0  ...                   82.0
# 3134                  109.0   94.0     76.0  ...                   93.0
# 3135                  104.0   91.0     36.0  ...                   31.0
# 3136                   50.0   71.0     98.0  ...                  101.0
# 3137                   17.0  113.0    109.0  ...                   44.0
#
#       Warden/ranger  Warehouse manager  Waste management officer  \
# 0              21.0                4.0                      44.0
# 1              96.0               74.0                      52.0
# 2              23.0               52.0                      42.0
# 3              45.0               20.0                      44.0
# 4              21.0              112.0                      64.0
# ...             ...                ...                       ...
# 3133           87.0               72.0                     100.0
# 3134           22.0              107.0                      25.0
# 3135           81.0               24.0                      81.0
# 3136          118.0              103.0                      88.0
# 3137          102.0               60.0                     104.0
#
#       Water engineer  Water quality scientist  Web designer  \
# 0               96.0                     78.0         112.0
# 1               59.0                    114.0         100.0
# 2              110.0                     45.0           5.0
# 3               84.0                     90.0          31.0
# 4               94.0                     56.0          83.0
# ...              ...                      ...           ...
# 3133            35.0                     18.0          22.0
# 3134            87.0                    108.0          16.0
# 3135           112.0                     78.0          26.0
# 3136            88.0                     18.0          67.0
# 3137            88.0                     58.0          39.0
#
#       Wellsite geologist  Writer  Youth worker
# 0                    3.0    78.0           6.0
# 1                   35.0    87.0          76.0
# 2                   86.0    15.0          50.0
# 3                   54.0    63.0           3.0
# 4                   94.0   104.0          32.0
# ...                  ...     ...           ...
# 3133                86.0    71.0          92.0
# 3134                19.0    47.0          81.0
# 3135                43.0    97.0          12.0
# 3136                29.0    22.0          86.0
# 3137                53.0     8.0          83.0
#
# [2907 rows x 640 columns]

# %%
X = df1.iloc[:,1:] # selecting all columns except Gender | Dependent variable
y = df1.iloc[:,0] # selecting column Gender as our target variable | Independent variable

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
model = Sequential()
model.add(Dense(10,input_dim=639,activation='relu')) # First layer
model.add(Dense(10,activation='relu')) # Second layer
model.add(Dense(1,activation='sigmoid'))

# %%
# Compile the model
model.compile(loss="binary_crossentropy",optimizer='adam',metrics=['accuracy'])

# %%
# Train the model
history = model.fit(X, y, epochs=150, batch_size=512, verbose=2)
# Out:
# Epoch 1/150
# 6/6 - 0s - loss: 0.7371 - accuracy: 0.5067 - 443ms/epoch - 74ms/step
# Epoch 2/150
# 6/6 - 0s - loss: 0.6990 - accuracy: 0.5518 - 16ms/epoch - 3ms/step
# Epoch 3/150
# 6/6 - 0s - loss: 0.6725 - accuracy: 0.5955 - 20ms/epoch - 3ms/step
# Epoch 4/150
# 6/6 - 0s - loss: 0.6523 - accuracy: 0.6250 - 18ms/epoch - 3ms/step
# Epoch 5/150
# 6/6 - 0s - loss: 0.6348 - accuracy: 0.6474 - 21ms/epoch - 3ms/step
# Epoch 6/150
# 6/6 - 0s - loss: 0.6193 - accuracy: 0.6773 - 16ms/epoch - 3ms/step
# Epoch 7/150
# 6/6 - 0s - loss: 0.6043 - accuracy: 0.6973 - 19ms/epoch - 3ms/step
# Epoch 8/150
# 6/6 - 0s - loss: 0.5896 - accuracy: 0.7138 - 22ms/epoch - 4ms/step
# Epoch 9/150
# 6/6 - 0s - loss: 0.5750 - accuracy: 0.7355 - 15ms/epoch - 2ms/step
# Epoch 10/150
# 6/6 - 0s - loss: 0.5605 - accuracy: 0.7506 - 18ms/epoch - 3ms/step
# Epoch 11/150
# 6/6 - 0s - loss: 0.5460 - accuracy: 0.7650 - 19ms/epoch - 3ms/step
# Epoch 12/150
# 6/6 - 0s - loss: 0.5313 - accuracy: 0.7850 - 17ms/epoch - 3ms/step
# Epoch 13/150
# 6/6 - 0s - loss: 0.5164 - accuracy: 0.7953 - 16ms/epoch - 3ms/step
# Epoch 14/150
# 6/6 - 0s - loss: 0.5008 - accuracy: 0.8060 - 17ms/epoch - 3ms/step
# Epoch 15/150
# 6/6 - 0s - loss: 0.4854 - accuracy: 0.8177 - 18ms/epoch - 3ms/step
# Epoch 16/150
# 6/6 - 0s - loss: 0.4701 - accuracy: 0.8304 - 16ms/epoch - 3ms/step
# Epoch 17/150
# 6/6 - 0s - loss: 0.4542 - accuracy: 0.8407 - 17ms/epoch - 3ms/step
# Epoch 18/150
# 6/6 - 0s - loss: 0.4380 - accuracy: 0.8486 - 13ms/epoch - 2ms/step
# Epoch 19/150
# 6/6 - 0s - loss: 0.4219 - accuracy: 0.8548 - 17ms/epoch - 3ms/step
# Epoch 20/150
# 6/6 - 0s - loss: 0.4057 - accuracy: 0.8665 - 17ms/epoch - 3ms/step
# Epoch 21/150
# 6/6 - 0s - loss: 0.3896 - accuracy: 0.8738 - 17ms/epoch - 3ms/step
# Epoch 22/150
# 6/6 - 0s - loss: 0.3737 - accuracy: 0.8854 - 18ms/epoch - 3ms/step
# Epoch 23/150
# 6/6 - 0s - loss: 0.3579 - accuracy: 0.8930 - 17ms/epoch - 3ms/step
# Epoch 24/150
# 6/6 - 0s - loss: 0.3423 - accuracy: 0.8999 - 17ms/epoch - 3ms/step
# Epoch 25/150
# 6/6 - 0s - loss: 0.3272 - accuracy: 0.9023 - 18ms/epoch - 3ms/step
# Epoch 26/150
# 6/6 - 0s - loss: 0.3125 - accuracy: 0.9075 - 17ms/epoch - 3ms/step
# Epoch 27/150
# 6/6 - 0s - loss: 0.2981 - accuracy: 0.9119 - 20ms/epoch - 3ms/step
# Epoch 28/150
# 6/6 - 0s - loss: 0.2840 - accuracy: 0.9188 - 18ms/epoch - 3ms/step
# Epoch 29/150
# 6/6 - 0s - loss: 0.2708 - accuracy: 0.9240 - 11ms/epoch - 2ms/step
# Epoch 30/150
# 6/6 - 0s - loss: 0.2578 - accuracy: 0.9278 - 17ms/epoch - 3ms/step
# Epoch 31/150
# 6/6 - 0s - loss: 0.2452 - accuracy: 0.9370 - 24ms/epoch - 4ms/step
# Epoch 32/150
# 6/6 - 0s - loss: 0.2331 - accuracy: 0.9419 - 17ms/epoch - 3ms/step
# Epoch 33/150
# 6/6 - 0s - loss: 0.2214 - accuracy: 0.9474 - 16ms/epoch - 3ms/step
# Epoch 34/150
# 6/6 - 0s - loss: 0.2099 - accuracy: 0.9522 - 18ms/epoch - 3ms/step
# Epoch 35/150
# 6/6 - 0s - loss: 0.1991 - accuracy: 0.9549 - 18ms/epoch - 3ms/step
# Epoch 36/150
# 6/6 - 0s - loss: 0.1888 - accuracy: 0.9563 - 18ms/epoch - 3ms/step
# Epoch 37/150
# 6/6 - 0s - loss: 0.1791 - accuracy: 0.9591 - 16ms/epoch - 3ms/step
# Epoch 38/150
# 6/6 - 0s - loss: 0.1698 - accuracy: 0.9622 - 15ms/epoch - 2ms/step
# Epoch 39/150
# 6/6 - 0s - loss: 0.1607 - accuracy: 0.9684 - 19ms/epoch - 3ms/step
# Epoch 40/150
# 6/6 - 0s - loss: 0.1524 - accuracy: 0.9708 - 19ms/epoch - 3ms/step
# Epoch 41/150
# 6/6 - 0s - loss: 0.1445 - accuracy: 0.9718 - 18ms/epoch - 3ms/step
# Epoch 42/150
# 6/6 - 0s - loss: 0.1367 - accuracy: 0.9739 - 18ms/epoch - 3ms/step
# Epoch 43/150
# 6/6 - 0s - loss: 0.1294 - accuracy: 0.9749 - 12ms/epoch - 2ms/step
# Epoch 44/150
# 6/6 - 0s - loss: 0.1226 - accuracy: 0.9766 - 17ms/epoch - 3ms/step
# Epoch 45/150
# 6/6 - 0s - loss: 0.1161 - accuracy: 0.9790 - 14ms/epoch - 2ms/step
# Epoch 46/150
# 6/6 - 0s - loss: 0.1101 - accuracy: 0.9797 - 16ms/epoch - 3ms/step
# Epoch 47/150
# 6/6 - 0s - loss: 0.1045 - accuracy: 0.9804 - 17ms/epoch - 3ms/step
# Epoch 48/150
# 6/6 - 0s - loss: 0.0993 - accuracy: 0.9835 - 17ms/epoch - 3ms/step
# Epoch 49/150
# 6/6 - 0s - loss: 0.0944 - accuracy: 0.9835 - 16ms/epoch - 3ms/step
# Epoch 50/150
# 6/6 - 0s - loss: 0.0898 - accuracy: 0.9845 - 18ms/epoch - 3ms/step
# Epoch 51/150
# 6/6 - 0s - loss: 0.0855 - accuracy: 0.9852 - 17ms/epoch - 3ms/step
# Epoch 52/150
# 6/6 - 0s - loss: 0.0815 - accuracy: 0.9856 - 17ms/epoch - 3ms/step
# Epoch 53/150
# 6/6 - 0s - loss: 0.0778 - accuracy: 0.9862 - 17ms/epoch - 3ms/step
# Epoch 54/150
# 6/6 - 0s - loss: 0.0742 - accuracy: 0.9876 - 21ms/epoch - 3ms/step
# Epoch 55/150
# 6/6 - 0s - loss: 0.0707 - accuracy: 0.9883 - 21ms/epoch - 4ms/step
# Epoch 56/150
# 6/6 - 0s - loss: 0.0676 - accuracy: 0.9890 - 14ms/epoch - 2ms/step
# Epoch 57/150
# 6/6 - 0s - loss: 0.0647 - accuracy: 0.9893 - 13ms/epoch - 2ms/step
# Epoch 58/150
# 6/6 - 0s - loss: 0.0620 - accuracy: 0.9893 - 5ms/epoch - 800us/step
# Epoch 59/150
# 6/6 - 0s - loss: 0.0595 - accuracy: 0.9893 - 6ms/epoch - 996us/step
# Epoch 60/150
# 6/6 - 0s - loss: 0.0570 - accuracy: 0.9893 - 17ms/epoch - 3ms/step
# Epoch 61/150
# 6/6 - 0s - loss: 0.0548 - accuracy: 0.9897 - 20ms/epoch - 3ms/step
# Epoch 62/150
# 6/6 - 0s - loss: 0.0528 - accuracy: 0.9900 - 12ms/epoch - 2ms/step
# Epoch 63/150
# 6/6 - 0s - loss: 0.0507 - accuracy: 0.9904 - 16ms/epoch - 3ms/step
# Epoch 64/150
# 6/6 - 0s - loss: 0.0489 - accuracy: 0.9907 - 21ms/epoch - 4ms/step
# Epoch 65/150
# 6/6 - 0s - loss: 0.0470 - accuracy: 0.9911 - 13ms/epoch - 2ms/step
# Epoch 66/150
# 6/6 - 0s - loss: 0.0453 - accuracy: 0.9921 - 16ms/epoch - 3ms/step
# Epoch 67/150
# 6/6 - 0s - loss: 0.0437 - accuracy: 0.9921 - 19ms/epoch - 3ms/step
# Epoch 68/150
# 6/6 - 0s - loss: 0.0421 - accuracy: 0.9921 - 12ms/epoch - 2ms/step
# Epoch 69/150
# 6/6 - 0s - loss: 0.0406 - accuracy: 0.9921 - 17ms/epoch - 3ms/step
# Epoch 70/150
# 6/6 - 0s - loss: 0.0391 - accuracy: 0.9921 - 15ms/epoch - 3ms/step
# Epoch 71/150
# 6/6 - 0s - loss: 0.0378 - accuracy: 0.9921 - 15ms/epoch - 2ms/step
# Epoch 72/150
# 6/6 - 0s - loss: 0.0366 - accuracy: 0.9924 - 13ms/epoch - 2ms/step
# Epoch 73/150
# 6/6 - 0s - loss: 0.0354 - accuracy: 0.9924 - 14ms/epoch - 2ms/step
# Epoch 74/150
# 6/6 - 0s - loss: 0.0343 - accuracy: 0.9924 - 14ms/epoch - 2ms/step
# Epoch 75/150
# 6/6 - 0s - loss: 0.0332 - accuracy: 0.9924 - 14ms/epoch - 2ms/step
# Epoch 76/150
# 6/6 - 0s - loss: 0.0322 - accuracy: 0.9924 - 5ms/epoch - 863us/step
# Epoch 77/150
# 6/6 - 0s - loss: 0.0312 - accuracy: 0.9924 - 5ms/epoch - 889us/step
# Epoch 78/150
# 6/6 - 0s - loss: 0.0303 - accuracy: 0.9928 - 7ms/epoch - 1ms/step
# Epoch 79/150
# 6/6 - 0s - loss: 0.0294 - accuracy: 0.9928 - 16ms/epoch - 3ms/step
# Epoch 80/150
# 6/6 - 0s - loss: 0.0287 - accuracy: 0.9928 - 21ms/epoch - 4ms/step
# Epoch 81/150
# 6/6 - 0s - loss: 0.0279 - accuracy: 0.9928 - 12ms/epoch - 2ms/step
# Epoch 82/150
# 6/6 - 0s - loss: 0.0272 - accuracy: 0.9928 - 21ms/epoch - 3ms/step
# Epoch 83/150
# 6/6 - 0s - loss: 0.0265 - accuracy: 0.9928 - 13ms/epoch - 2ms/step
# Epoch 84/150
# 6/6 - 0s - loss: 0.0258 - accuracy: 0.9928 - 16ms/epoch - 3ms/step
# Epoch 85/150
# 6/6 - 0s - loss: 0.0252 - accuracy: 0.9928 - 7ms/epoch - 1ms/step
# Epoch 86/150
# 6/6 - 0s - loss: 0.0245 - accuracy: 0.9928 - 21ms/epoch - 3ms/step
# Epoch 87/150
# 6/6 - 0s - loss: 0.0239 - accuracy: 0.9928 - 13ms/epoch - 2ms/step
# Epoch 88/150
# 6/6 - 0s - loss: 0.0233 - accuracy: 0.9928 - 16ms/epoch - 3ms/step
# Epoch 89/150
# 6/6 - 0s - loss: 0.0228 - accuracy: 0.9928 - 17ms/epoch - 3ms/step
# Epoch 90/150
# 6/6 - 0s - loss: 0.0222 - accuracy: 0.9928 - 16ms/epoch - 3ms/step
# Epoch 91/150
# 6/6 - 0s - loss: 0.0217 - accuracy: 0.9928 - 27ms/epoch - 4ms/step
# Epoch 92/150
# 6/6 - 0s - loss: 0.0212 - accuracy: 0.9931 - 17ms/epoch - 3ms/step
# Epoch 93/150
# 6/6 - 0s - loss: 0.0207 - accuracy: 0.9931 - 17ms/epoch - 3ms/step
# Epoch 94/150
# 6/6 - 0s - loss: 0.0203 - accuracy: 0.9931 - 17ms/epoch - 3ms/step
# Epoch 95/150
# 6/6 - 0s - loss: 0.0198 - accuracy: 0.9931 - 20ms/epoch - 3ms/step
# Epoch 96/150
# 6/6 - 0s - loss: 0.0193 - accuracy: 0.9931 - 20ms/epoch - 3ms/step
# Epoch 97/150
# 6/6 - 0s - loss: 0.0189 - accuracy: 0.9931 - 15ms/epoch - 3ms/step
# Epoch 98/150
# 6/6 - 0s - loss: 0.0185 - accuracy: 0.9935 - 6ms/epoch - 979us/step
# Epoch 99/150
# 6/6 - 0s - loss: 0.0181 - accuracy: 0.9945 - 6ms/epoch - 1ms/step
# Epoch 100/150
# 6/6 - 0s - loss: 0.0178 - accuracy: 0.9945 - 7ms/epoch - 1ms/step
# Epoch 101/150
# 6/6 - 0s - loss: 0.0173 - accuracy: 0.9952 - 17ms/epoch - 3ms/step
# Epoch 102/150
# 6/6 - 0s - loss: 0.0169 - accuracy: 0.9959 - 17ms/epoch - 3ms/step
# Epoch 103/150
# 6/6 - 0s - loss: 0.0165 - accuracy: 0.9986 - 20ms/epoch - 3ms/step
# Epoch 104/150
# 6/6 - 0s - loss: 0.0161 - accuracy: 0.9986 - 13ms/epoch - 2ms/step
# Epoch 105/150
# 6/6 - 0s - loss: 0.0158 - accuracy: 0.9986 - 13ms/epoch - 2ms/step
# Epoch 106/150
# 6/6 - 0s - loss: 0.0155 - accuracy: 0.9986 - 16ms/epoch - 3ms/step
# Epoch 107/150
# 6/6 - 0s - loss: 0.0152 - accuracy: 0.9986 - 17ms/epoch - 3ms/step
# Epoch 108/150
# 6/6 - 0s - loss: 0.0150 - accuracy: 0.9986 - 16ms/epoch - 3ms/step
# Epoch 109/150
# 6/6 - 0s - loss: 0.0147 - accuracy: 0.9990 - 15ms/epoch - 2ms/step
# Epoch 110/150
# 6/6 - 0s - loss: 0.0145 - accuracy: 0.9990 - 14ms/epoch - 2ms/step
# Epoch 111/150
# 6/6 - 0s - loss: 0.0142 - accuracy: 0.9983 - 13ms/epoch - 2ms/step
# Epoch 112/150
# 6/6 - 0s - loss: 0.0140 - accuracy: 0.9983 - 3ms/epoch - 444us/step
# Epoch 113/150
# 6/6 - 0s - loss: 0.0137 - accuracy: 0.9983 - 13ms/epoch - 2ms/step
# Epoch 114/150
# 6/6 - 0s - loss: 0.0135 - accuracy: 0.9983 - 4ms/epoch - 653us/step
# Epoch 115/150
# 6/6 - 0s - loss: 0.0132 - accuracy: 0.9983 - 16ms/epoch - 3ms/step
# Epoch 116/150
# 6/6 - 0s - loss: 0.0130 - accuracy: 0.9983 - 24ms/epoch - 4ms/step
# Epoch 117/150
# 6/6 - 0s - loss: 0.0128 - accuracy: 0.9986 - 9ms/epoch - 2ms/step
# Epoch 118/150
# 6/6 - 0s - loss: 0.0126 - accuracy: 0.9986 - 17ms/epoch - 3ms/step
# Epoch 119/150
# 6/6 - 0s - loss: 0.0124 - accuracy: 0.9986 - 16ms/epoch - 3ms/step
# Epoch 120/150
# 6/6 - 0s - loss: 0.0122 - accuracy: 0.9986 - 17ms/epoch - 3ms/step
# Epoch 121/150
# 6/6 - 0s - loss: 0.0120 - accuracy: 0.9986 - 17ms/epoch - 3ms/step
# Epoch 122/150
# 6/6 - 0s - loss: 0.0118 - accuracy: 0.9986 - 16ms/epoch - 3ms/step
# Epoch 123/150
# 6/6 - 0s - loss: 0.0116 - accuracy: 0.9986 - 17ms/epoch - 3ms/step
# Epoch 124/150
# 6/6 - 0s - loss: 0.0114 - accuracy: 0.9986 - 16ms/epoch - 3ms/step
# Epoch 125/150
# 6/6 - 0s - loss: 0.0112 - accuracy: 0.9986 - 17ms/epoch - 3ms/step
# Epoch 126/150
# 6/6 - 0s - loss: 0.0110 - accuracy: 0.9986 - 17ms/epoch - 3ms/step
# Epoch 127/150
# 6/6 - 0s - loss: 0.0109 - accuracy: 0.9986 - 17ms/epoch - 3ms/step
# Epoch 128/150
# 6/6 - 0s - loss: 0.0107 - accuracy: 0.9986 - 17ms/epoch - 3ms/step
# Epoch 129/150
# 6/6 - 0s - loss: 0.0104 - accuracy: 0.9986 - 10ms/epoch - 2ms/step
# Epoch 130/150
# 6/6 - 0s - loss: 0.0102 - accuracy: 0.9986 - 16ms/epoch - 3ms/step
# Epoch 131/150
# 6/6 - 0s - loss: 0.0100 - accuracy: 0.9990 - 23ms/epoch - 4ms/step
# Epoch 132/150
# 6/6 - 0s - loss: 0.0099 - accuracy: 0.9990 - 7ms/epoch - 1ms/step
# Epoch 133/150
# 6/6 - 0s - loss: 0.0097 - accuracy: 0.9990 - 17ms/epoch - 3ms/step
# Epoch 134/150
# 6/6 - 0s - loss: 0.0096 - accuracy: 0.9990 - 17ms/epoch - 3ms/step
# Epoch 135/150
# 6/6 - 0s - loss: 0.0095 - accuracy: 0.9990 - 9ms/epoch - 2ms/step
# Epoch 136/150
# 6/6 - 0s - loss: 0.0093 - accuracy: 0.9990 - 16ms/epoch - 3ms/step
# Epoch 137/150
# 6/6 - 0s - loss: 0.0092 - accuracy: 0.9990 - 20ms/epoch - 3ms/step
# Epoch 138/150
# 6/6 - 0s - loss: 0.0090 - accuracy: 0.9990 - 21ms/epoch - 4ms/step
# Epoch 139/150
# 6/6 - 0s - loss: 0.0087 - accuracy: 0.9993 - 8ms/epoch - 1ms/step
# Epoch 140/150
# 6/6 - 0s - loss: 0.0086 - accuracy: 0.9993 - 25ms/epoch - 4ms/step
# Epoch 141/150
# 6/6 - 0s - loss: 0.0084 - accuracy: 0.9993 - 9ms/epoch - 1ms/step
# Epoch 142/150
# 6/6 - 0s - loss: 0.0082 - accuracy: 0.9993 - 5ms/epoch - 771us/step
# Epoch 143/150
# 6/6 - 0s - loss: 0.0081 - accuracy: 0.9993 - 23ms/epoch - 4ms/step
# Epoch 144/150
# 6/6 - 0s - loss: 0.0079 - accuracy: 0.9993 - 17ms/epoch - 3ms/step
# Epoch 145/150
# 6/6 - 0s - loss: 0.0077 - accuracy: 0.9993 - 15ms/epoch - 3ms/step
# Epoch 146/150
# 6/6 - 0s - loss: 0.0076 - accuracy: 0.9993 - 16ms/epoch - 3ms/step
# Epoch 147/150
# 6/6 - 0s - loss: 0.0075 - accuracy: 0.9993 - 16ms/epoch - 3ms/step
# Epoch 148/150
# 6/6 - 0s - loss: 0.0074 - accuracy: 0.9993 - 17ms/epoch - 3ms/step
# Epoch 149/150
# 6/6 - 0s - loss: 0.0073 - accuracy: 0.9993 - 17ms/epoch - 3ms/step
# Epoch 150/150
# 6/6 - 0s - loss: 0.0072 - accuracy: 0.9993 - 16ms/epoch - 3ms/step

# %%
# Converting history into a DataFrame
history_df1 = pd.DataFrame(history.history)

# %%
# Extracting epochs
epochs = range(1, len(history_df1) + 1)

# Plotting Training Accuracy
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, history_df1['accuracy'], label='Training Accuracy', color='blue')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.suptitle("Model Training 2: Accuracy and Loss Over Epochs")

# Plotting Training Loss
plt.subplot(1, 2, 2)
plt.plot(epochs, history_df1['loss'], label='Training Loss', color='red')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Results have improved, lets drop outliers to see if we can get better score.

# %%
df2
# Out:
#          Gender                         Job_Title  Age
# 0             1                  Technical brewer    4
# 1             1          Teacher, adult education  115
# 2             0  Armed forces operational officer   60
# 3             0                       Ship broker   15
# 4             0                     Media planner   27
# ...         ...                               ...  ...
# 1999995       1        Research scientist (maths)  111
# 1999996       0               Marketing executive   47
# 1999997       1                      Photographer   64
# 1999998       0              Chartered accountant  113
# 1999999       0                        Printmaker   63
#
# [2000000 rows x 3 columns]

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.boxplot(df2.Age, vert=False)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.yticks([])  # Hide y-axis labels for clarity as there's only one dataset
plt.grid(True)
plt.show()

# %% [markdown]
# Dropping rows for people likely too young or retired (not in the typical working age range). Assuming the working age range is from 16 to 65 years old.

# %%
# Defining working age range
min_working_age = 16
max_working_age = 65

# Filter the DataFrame to keep only rows where 'Age' is within the working age range
df2 = df2[(df2['Age'] >= min_working_age) & (df2['Age'] <= max_working_age)]

# %%
df2
# Out:
#          Gender                                          Job_Title  Age
# 2             0                   Armed forces operational officer   60
# 4             0                                      Media planner   27
# 6             0  Historic buildings inspector/conservation officer   49
# 7             1                                   Engineer, mining   58
# 9             1                                   Graphic designer   61
# ...         ...                                                ...  ...
# 1999991       0                                   Network engineer   42
# 1999994       0                 Government social research officer   57
# 1999996       0                                Marketing executive   47
# 1999997       1                                       Photographer   64
# 1999999       0                                         Printmaker   63
#
# [862202 rows x 3 columns]

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.boxplot(df2.Age, vert=False)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.yticks([])  # Hide y-axis labels for clarity as there's only one dataset
plt.grid(True)
plt.show()

# %%
# Add a unique identifier for each row within each group of 'Sex' and 'Job_Title'
df2['unique_id'] = df2.groupby(['Gender', 'Job_Title']).cumcount()

# Pivot the table, using 'Sex' and 'unique_id' as the index
df2 = df2.pivot_table(index=['Gender', 'unique_id'], columns='Job_Title', values='Age').reset_index()
df2  = df2.rename_axis(None, axis=1) # Index with no name as it should be

# Drop the 'unique_id' column as it's no longer needed, keeping 'Sex'
df2.drop('unique_id', axis=1, inplace=True)

# Display the result
df2
# Out:
# C:\Users\jose\AppData\Local\Temp\ipykernel_11672\1944859778.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['unique_id'] = df2.groupby(['Gender', 'Job_Title']).cumcount()
#       Gender  Academic librarian  Accommodation manager  \
# 0          0                25.0                   35.0
# 1          0                53.0                   32.0
# 2          0                52.0                   16.0
# 3          0                62.0                   17.0
# 4          0                58.0                   40.0
# ...      ...                 ...                    ...
# 1530       1                 NaN                    NaN
# 1531       1                 NaN                    NaN
# 1532       1                 NaN                    NaN
# 1533       1                 NaN                    NaN
# 1534       1                 NaN                    NaN
#
#       Accountant, chartered  Accountant, chartered certified  \
# 0                      54.0                             40.0
# 1                      40.0                             44.0
# 2                      22.0                             27.0
# 3                      37.0                             46.0
# 4                      60.0                             22.0
# ...                     ...                              ...
# 1530                    NaN                              NaN
# 1531                    NaN                              NaN
# 1532                    NaN                              NaN
# 1533                    NaN                              NaN
# 1534                    NaN                              NaN
#
#       Accountant, chartered management  Accountant, chartered public finance  \
# 0                                 41.0                                  35.0
# 1                                 57.0                                  55.0
# 2                                 26.0                                  60.0
# 3                                 26.0                                  26.0
# 4                                 41.0                                  28.0
# ...                                ...                                   ...
# 1530                               NaN                                   NaN
# 1531                               NaN                                   NaN
# 1532                               NaN                                   NaN
# 1533                               NaN                                   NaN
# 1534                               NaN                                   NaN
#
#       Accounting technician  Actor  Actuary  ...  Volunteer coordinator  \
# 0                      60.0   34.0     34.0  ...                   17.0
# 1                      16.0   43.0     40.0  ...                   19.0
# 2                      35.0   52.0     59.0  ...                   65.0
# 3                      65.0   51.0     27.0  ...                   35.0
# 4                      62.0   41.0     38.0  ...                   17.0
# ...                     ...    ...      ...  ...                    ...
# 1530                    NaN    NaN      NaN  ...                    NaN
# 1531                    NaN    NaN      NaN  ...                    NaN
# 1532                    NaN    NaN      NaN  ...                    NaN
# 1533                    NaN    NaN      NaN  ...                    NaN
# 1534                    NaN    NaN      NaN  ...                    NaN
#
#       Warden/ranger  Warehouse manager  Waste management officer  \
# 0              21.0               52.0                      44.0
# 1              23.0               20.0                      52.0
# 2              45.0               31.0                      42.0
# 3              21.0               42.0                      44.0
# 4              17.0               63.0                      64.0
# ...             ...                ...                       ...
# 1530            NaN                NaN                       NaN
# 1531            NaN                NaN                       NaN
# 1532            NaN                NaN                       NaN
# 1533            NaN                NaN                       NaN
# 1534            NaN                NaN                       NaN
#
#       Water engineer  Water quality scientist  Web designer  \
# 0               59.0                     45.0          31.0
# 1               48.0                     56.0          31.0
# 2               21.0                     48.0          24.0
# 3               44.0                     54.0          18.0
# 4               34.0                     24.0          23.0
# ...              ...                      ...           ...
# 1530             NaN                      NaN           NaN
# 1531             NaN                      NaN           NaN
# 1532             NaN                      NaN           NaN
# 1533             NaN                      NaN           NaN
# 1534             NaN                      NaN           NaN
#
#       Wellsite geologist  Writer  Youth worker
# 0                   35.0    63.0          50.0
# 1                   54.0    54.0          32.0
# 2                   36.0    20.0          59.0
# 3                   44.0    52.0          18.0
# 4                   48.0    50.0          28.0
# ...                  ...     ...           ...
# 1530                 NaN     NaN           NaN
# 1531                 NaN     NaN           NaN
# 1532                 NaN     NaN           NaN
# 1533                 NaN     NaN           NaN
# 1534                 NaN     NaN           NaN
#
# [1535 rows x 640 columns]

# %%
df2 = df2.dropna()

# %%
df2
# Out:
#       Gender  Academic librarian  Accommodation manager  \
# 0          0                25.0                   35.0
# 1          0                53.0                   32.0
# 2          0                52.0                   16.0
# 3          0                62.0                   17.0
# 4          0                58.0                   40.0
# ...      ...                 ...                    ...
# 1337       1                58.0                   48.0
# 1338       1                64.0                   63.0
# 1339       1                54.0                   54.0
# 1340       1                59.0                   53.0
# 1341       1                18.0                   63.0
#
#       Accountant, chartered  Accountant, chartered certified  \
# 0                      54.0                             40.0
# 1                      40.0                             44.0
# 2                      22.0                             27.0
# 3                      37.0                             46.0
# 4                      60.0                             22.0
# ...                     ...                              ...
# 1337                   46.0                             26.0
# 1338                   45.0                             21.0
# 1339                   38.0                             57.0
# 1340                   54.0                             28.0
# 1341                   18.0                             39.0
#
#       Accountant, chartered management  Accountant, chartered public finance  \
# 0                                 41.0                                  35.0
# 1                                 57.0                                  55.0
# 2                                 26.0                                  60.0
# 3                                 26.0                                  26.0
# 4                                 41.0                                  28.0
# ...                                ...                                   ...
# 1337                              51.0                                  43.0
# 1338                              37.0                                  60.0
# 1339                              32.0                                  58.0
# 1340                              52.0                                  17.0
# 1341                              21.0                                  61.0
#
#       Accounting technician  Actor  Actuary  ...  Volunteer coordinator  \
# 0                      60.0   34.0     34.0  ...                   17.0
# 1                      16.0   43.0     40.0  ...                   19.0
# 2                      35.0   52.0     59.0  ...                   65.0
# 3                      65.0   51.0     27.0  ...                   35.0
# 4                      62.0   41.0     38.0  ...                   17.0
# ...                     ...    ...      ...  ...                    ...
# 1337                   50.0   38.0     21.0  ...                   35.0
# 1338                   63.0   52.0     16.0  ...                   64.0
# 1339                   35.0   60.0     16.0  ...                   48.0
# 1340                   32.0   43.0     39.0  ...                   56.0
# 1341                   45.0   58.0     20.0  ...                   55.0
#
#       Warden/ranger  Warehouse manager  Waste management officer  \
# 0              21.0               52.0                      44.0
# 1              23.0               20.0                      52.0
# 2              45.0               31.0                      42.0
# 3              21.0               42.0                      44.0
# 4              17.0               63.0                      64.0
# ...             ...                ...                       ...
# 1337           51.0               21.0                      23.0
# 1338           42.0               31.0                      25.0
# 1339           25.0               23.0                      54.0
# 1340           52.0               26.0                      30.0
# 1341           47.0               32.0                      41.0
#
#       Water engineer  Water quality scientist  Web designer  \
# 0               59.0                     45.0          31.0
# 1               48.0                     56.0          31.0
# 2               21.0                     48.0          24.0
# 3               44.0                     54.0          18.0
# 4               34.0                     24.0          23.0
# ...              ...                      ...           ...
# 1337            49.0                     44.0          34.0
# 1338            45.0                     20.0          46.0
# 1339            28.0                     64.0          28.0
# 1340            48.0                     54.0          37.0
# 1341            63.0                     52.0          17.0
#
#       Wellsite geologist  Writer  Youth worker
# 0                   35.0    63.0          50.0
# 1                   54.0    54.0          32.0
# 2                   36.0    20.0          59.0
# 3                   44.0    52.0          18.0
# 4                   48.0    50.0          28.0
# ...                  ...     ...           ...
# 1337                27.0    59.0          52.0
# 1338                56.0    24.0          65.0
# 1339                65.0    34.0          32.0
# 1340                37.0    65.0          16.0
# 1341                61.0    35.0          16.0
#
# [1184 rows x 640 columns]

# %%
X = df2.iloc[:,1:] # selecting all columns except column 8 | Dependent variable
y = df2.iloc[:,0] # selecting column 8 as our target variable | Independent variable

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
model = Sequential()
model.add(Dense(10,input_dim=639,activation='relu')) # First layer
model.add(Dense(10,activation='relu')) # Second layer
model.add(Dense(1,activation='sigmoid'))

# %%
# Compile the model
model.compile(loss="binary_crossentropy",optimizer='adam',metrics=['accuracy'])

# %%
# Train the model
history = model.fit(X, y, epochs=150, batch_size=512, verbose=2)
# Out:
# Epoch 1/150
# 3/3 - 0s - loss: 0.8940 - accuracy: 0.5076 - 434ms/epoch - 145ms/step
# Epoch 2/150
# 3/3 - 0s - loss: 0.8376 - accuracy: 0.5203 - 9ms/epoch - 3ms/step
# Epoch 3/150
# 3/3 - 0s - loss: 0.7946 - accuracy: 0.5304 - 14ms/epoch - 5ms/step
# Epoch 4/150
# 3/3 - 0s - loss: 0.7560 - accuracy: 0.5532 - 16ms/epoch - 5ms/step
# Epoch 5/150
# 3/3 - 0s - loss: 0.7231 - accuracy: 0.5701 - 14ms/epoch - 5ms/step
# Epoch 6/150
# 3/3 - 0s - loss: 0.6937 - accuracy: 0.5878 - 3ms/epoch - 936us/step
# Epoch 7/150
# 3/3 - 0s - loss: 0.6677 - accuracy: 0.6073 - 7ms/epoch - 2ms/step
# Epoch 8/150
# 3/3 - 0s - loss: 0.6444 - accuracy: 0.6334 - 16ms/epoch - 5ms/step
# Epoch 9/150
# 3/3 - 0s - loss: 0.6243 - accuracy: 0.6562 - 15ms/epoch - 5ms/step
# Epoch 10/150
# 3/3 - 0s - loss: 0.6059 - accuracy: 0.6757 - 14ms/epoch - 5ms/step
# Epoch 11/150
# 3/3 - 0s - loss: 0.5897 - accuracy: 0.7035 - 3ms/epoch - 1ms/step
# Epoch 12/150
# 3/3 - 0s - loss: 0.5747 - accuracy: 0.7213 - 8ms/epoch - 3ms/step
# Epoch 13/150
# 3/3 - 0s - loss: 0.5600 - accuracy: 0.7390 - 14ms/epoch - 5ms/step
# Epoch 14/150
# 3/3 - 0s - loss: 0.5468 - accuracy: 0.7584 - 15ms/epoch - 5ms/step
# Epoch 15/150
# 3/3 - 0s - loss: 0.5336 - accuracy: 0.7796 - 11ms/epoch - 4ms/step
# Epoch 16/150
# 3/3 - 0s - loss: 0.5212 - accuracy: 0.7905 - 9ms/epoch - 3ms/step
# Epoch 17/150
# 3/3 - 0s - loss: 0.5090 - accuracy: 0.8066 - 13ms/epoch - 4ms/step
# Epoch 18/150
# 3/3 - 0s - loss: 0.4973 - accuracy: 0.8117 - 14ms/epoch - 5ms/step
# Epoch 19/150
# 3/3 - 0s - loss: 0.4858 - accuracy: 0.8277 - 12ms/epoch - 4ms/step
# Epoch 20/150
# 3/3 - 0s - loss: 0.4742 - accuracy: 0.8353 - 6ms/epoch - 2ms/step
# Epoch 21/150
# 3/3 - 0s - loss: 0.4628 - accuracy: 0.8454 - 14ms/epoch - 5ms/step
# Epoch 22/150
# 3/3 - 0s - loss: 0.4516 - accuracy: 0.8547 - 13ms/epoch - 4ms/step
# Epoch 23/150
# 3/3 - 0s - loss: 0.4404 - accuracy: 0.8598 - 5ms/epoch - 2ms/step
# Epoch 24/150
# 3/3 - 0s - loss: 0.4294 - accuracy: 0.8716 - 14ms/epoch - 5ms/step
# Epoch 25/150
# 3/3 - 0s - loss: 0.4185 - accuracy: 0.8767 - 13ms/epoch - 4ms/step
# Epoch 26/150
# 3/3 - 0s - loss: 0.4077 - accuracy: 0.8826 - 3ms/epoch - 898us/step
# Epoch 27/150
# 3/3 - 0s - loss: 0.3971 - accuracy: 0.8919 - 15ms/epoch - 5ms/step
# Epoch 28/150
# 3/3 - 0s - loss: 0.3866 - accuracy: 0.8995 - 13ms/epoch - 4ms/step
# Epoch 29/150
# 3/3 - 0s - loss: 0.3760 - accuracy: 0.9003 - 2ms/epoch - 828us/step
# Epoch 30/150
# 3/3 - 0s - loss: 0.3657 - accuracy: 0.9029 - 17ms/epoch - 6ms/step
# Epoch 31/150
# 3/3 - 0s - loss: 0.3554 - accuracy: 0.9079 - 14ms/epoch - 5ms/step
# Epoch 32/150
# 3/3 - 0s - loss: 0.3452 - accuracy: 0.9130 - 12ms/epoch - 4ms/step
# Epoch 33/150
# 3/3 - 0s - loss: 0.3352 - accuracy: 0.9172 - 6ms/epoch - 2ms/step
# Epoch 34/150
# 3/3 - 0s - loss: 0.3255 - accuracy: 0.9181 - 15ms/epoch - 5ms/step
# Epoch 35/150
# 3/3 - 0s - loss: 0.3158 - accuracy: 0.9198 - 12ms/epoch - 4ms/step
# Epoch 36/150
# 3/3 - 0s - loss: 0.3064 - accuracy: 0.9223 - 4ms/epoch - 1ms/step
# Epoch 37/150
# 3/3 - 0s - loss: 0.2971 - accuracy: 0.9248 - 15ms/epoch - 5ms/step
# Epoch 38/150
# 3/3 - 0s - loss: 0.2881 - accuracy: 0.9265 - 11ms/epoch - 4ms/step
# Epoch 39/150
# 3/3 - 0s - loss: 0.2792 - accuracy: 0.9291 - 5ms/epoch - 2ms/step
# Epoch 40/150
# 3/3 - 0s - loss: 0.2706 - accuracy: 0.9324 - 7ms/epoch - 2ms/step
# Epoch 41/150
# 3/3 - 0s - loss: 0.2623 - accuracy: 0.9341 - 16ms/epoch - 5ms/step
# Epoch 42/150
# 3/3 - 0s - loss: 0.2542 - accuracy: 0.9367 - 12ms/epoch - 4ms/step
# Epoch 43/150
# 3/3 - 0s - loss: 0.2464 - accuracy: 0.9375 - 12ms/epoch - 4ms/step
# Epoch 44/150
# 3/3 - 0s - loss: 0.2386 - accuracy: 0.9409 - 7ms/epoch - 2ms/step
# Epoch 45/150
# 3/3 - 0s - loss: 0.2312 - accuracy: 0.9417 - 14ms/epoch - 5ms/step
# Epoch 46/150
# 3/3 - 0s - loss: 0.2238 - accuracy: 0.9443 - 10ms/epoch - 3ms/step
# Epoch 47/150
# 3/3 - 0s - loss: 0.2168 - accuracy: 0.9451 - 5ms/epoch - 2ms/step
# Epoch 48/150
# 3/3 - 0s - loss: 0.2100 - accuracy: 0.9468 - 14ms/epoch - 5ms/step
# Epoch 49/150
# 3/3 - 0s - loss: 0.2033 - accuracy: 0.9468 - 13ms/epoch - 4ms/step
# Epoch 50/150
# 3/3 - 0s - loss: 0.1968 - accuracy: 0.9476 - 3ms/epoch - 902us/step
# Epoch 51/150
# 3/3 - 0s - loss: 0.1905 - accuracy: 0.9485 - 7ms/epoch - 2ms/step
# Epoch 52/150
# 3/3 - 0s - loss: 0.1842 - accuracy: 0.9502 - 8ms/epoch - 3ms/step
# Epoch 53/150
# 3/3 - 0s - loss: 0.1781 - accuracy: 0.9502 - 9ms/epoch - 3ms/step
# Epoch 54/150
# 3/3 - 0s - loss: 0.1724 - accuracy: 0.9527 - 8ms/epoch - 3ms/step
# Epoch 55/150
# 3/3 - 0s - loss: 0.1668 - accuracy: 0.9535 - 6ms/epoch - 2ms/step
# Epoch 56/150
# 3/3 - 0s - loss: 0.1612 - accuracy: 0.9578 - 12ms/epoch - 4ms/step
# Epoch 57/150
# 3/3 - 0s - loss: 0.1561 - accuracy: 0.9595 - 12ms/epoch - 4ms/step
# Epoch 58/150
# 3/3 - 0s - loss: 0.1511 - accuracy: 0.9595 - 4ms/epoch - 1ms/step
# Epoch 59/150
# 3/3 - 0s - loss: 0.1463 - accuracy: 0.9603 - 15ms/epoch - 5ms/step
# Epoch 60/150
# 3/3 - 0s - loss: 0.1416 - accuracy: 0.9620 - 5ms/epoch - 2ms/step
# Epoch 61/150
# 3/3 - 0s - loss: 0.1369 - accuracy: 0.9628 - 5ms/epoch - 2ms/step
# Epoch 62/150
# 3/3 - 0s - loss: 0.1326 - accuracy: 0.9645 - 12ms/epoch - 4ms/step
# Epoch 63/150
# 3/3 - 0s - loss: 0.1283 - accuracy: 0.9654 - 5ms/epoch - 2ms/step
# Epoch 64/150
# 3/3 - 0s - loss: 0.1240 - accuracy: 0.9688 - 13ms/epoch - 4ms/step
# Epoch 65/150
# 3/3 - 0s - loss: 0.1200 - accuracy: 0.9688 - 0s/epoch - 0s/step
# Epoch 66/150
# 3/3 - 0s - loss: 0.1161 - accuracy: 0.9704 - 5ms/epoch - 2ms/step
# Epoch 67/150
# 3/3 - 0s - loss: 0.1123 - accuracy: 0.9713 - 14ms/epoch - 5ms/step
# Epoch 68/150
# 3/3 - 0s - loss: 0.1087 - accuracy: 0.9721 - 4ms/epoch - 1ms/step
# Epoch 69/150
# 3/3 - 0s - loss: 0.1050 - accuracy: 0.9730 - 13ms/epoch - 4ms/step
# Epoch 70/150
# 3/3 - 0s - loss: 0.1016 - accuracy: 0.9730 - 11ms/epoch - 4ms/step
# Epoch 71/150
# 3/3 - 0s - loss: 0.0983 - accuracy: 0.9738 - 4ms/epoch - 1ms/step
# Epoch 72/150
# 3/3 - 0s - loss: 0.0952 - accuracy: 0.9772 - 13ms/epoch - 4ms/step
# Epoch 73/150
# 3/3 - 0s - loss: 0.0921 - accuracy: 0.9780 - 0s/epoch - 0s/step
# Epoch 74/150
# 3/3 - 0s - loss: 0.0889 - accuracy: 0.9789 - 17ms/epoch - 6ms/step
# Epoch 75/150
# 3/3 - 0s - loss: 0.0860 - accuracy: 0.9797 - 5ms/epoch - 2ms/step
# Epoch 76/150
# 3/3 - 0s - loss: 0.0833 - accuracy: 0.9806 - 6ms/epoch - 2ms/step
# Epoch 77/150
# 3/3 - 0s - loss: 0.0805 - accuracy: 0.9814 - 12ms/epoch - 4ms/step
# Epoch 78/150
# 3/3 - 0s - loss: 0.0781 - accuracy: 0.9814 - 3ms/epoch - 1ms/step
# Epoch 79/150
# 3/3 - 0s - loss: 0.0757 - accuracy: 0.9814 - 15ms/epoch - 5ms/step
# Epoch 80/150
# 3/3 - 0s - loss: 0.0732 - accuracy: 0.9831 - 5ms/epoch - 2ms/step
# Epoch 81/150
# 3/3 - 0s - loss: 0.0708 - accuracy: 0.9831 - 5ms/epoch - 2ms/step
# Epoch 82/150
# 3/3 - 0s - loss: 0.0685 - accuracy: 0.9840 - 13ms/epoch - 4ms/step
# Epoch 83/150
# 3/3 - 0s - loss: 0.0663 - accuracy: 0.9848 - 0s/epoch - 0s/step
# Epoch 84/150
# 3/3 - 0s - loss: 0.0643 - accuracy: 0.9848 - 19ms/epoch - 6ms/step
# Epoch 85/150
# 3/3 - 0s - loss: 0.0624 - accuracy: 0.9865 - 12ms/epoch - 4ms/step
# Epoch 86/150
# 3/3 - 0s - loss: 0.0606 - accuracy: 0.9865 - 2ms/epoch - 587us/step
# Epoch 87/150
# 3/3 - 0s - loss: 0.0589 - accuracy: 0.9873 - 16ms/epoch - 5ms/step
# Epoch 88/150
# 3/3 - 0s - loss: 0.0572 - accuracy: 0.9873 - 9ms/epoch - 3ms/step
# Epoch 89/150
# 3/3 - 0s - loss: 0.0556 - accuracy: 0.9873 - 1ms/epoch - 485us/step
# Epoch 90/150
# 3/3 - 0s - loss: 0.0539 - accuracy: 0.9873 - 16ms/epoch - 5ms/step
# Epoch 91/150
# 3/3 - 0s - loss: 0.0524 - accuracy: 0.9882 - 13ms/epoch - 4ms/step
# Epoch 92/150
# 3/3 - 0s - loss: 0.0509 - accuracy: 0.9882 - 3ms/epoch - 855us/step
# Epoch 93/150
# 3/3 - 0s - loss: 0.0496 - accuracy: 0.9882 - 17ms/epoch - 6ms/step
# Epoch 94/150
# 3/3 - 0s - loss: 0.0482 - accuracy: 0.9890 - 10ms/epoch - 3ms/step
# Epoch 95/150
# 3/3 - 0s - loss: 0.0469 - accuracy: 0.9890 - 4ms/epoch - 1ms/step
# Epoch 96/150
# 3/3 - 0s - loss: 0.0456 - accuracy: 0.9890 - 16ms/epoch - 5ms/step
# Epoch 97/150
# 3/3 - 0s - loss: 0.0443 - accuracy: 0.9899 - 0s/epoch - 0s/step
# Epoch 98/150
# 3/3 - 0s - loss: 0.0431 - accuracy: 0.9899 - 5ms/epoch - 2ms/step
# Epoch 99/150
# 3/3 - 0s - loss: 0.0419 - accuracy: 0.9907 - 15ms/epoch - 5ms/step
# Epoch 100/150
# 3/3 - 0s - loss: 0.0408 - accuracy: 0.9916 - 4ms/epoch - 1ms/step
# Epoch 101/150
# 3/3 - 0s - loss: 0.0397 - accuracy: 0.9924 - 13ms/epoch - 4ms/step
# Epoch 102/150
# 3/3 - 0s - loss: 0.0386 - accuracy: 0.9924 - 13ms/epoch - 4ms/step
# Epoch 103/150
# 3/3 - 0s - loss: 0.0376 - accuracy: 0.9932 - 3ms/epoch - 1ms/step
# Epoch 104/150
# 3/3 - 0s - loss: 0.0366 - accuracy: 0.9932 - 10ms/epoch - 3ms/step
# Epoch 105/150
# 3/3 - 0s - loss: 0.0357 - accuracy: 0.9932 - 12ms/epoch - 4ms/step
# Epoch 106/150
# 3/3 - 0s - loss: 0.0348 - accuracy: 0.9932 - 10ms/epoch - 3ms/step
# Epoch 107/150
# 3/3 - 0s - loss: 0.0340 - accuracy: 0.9932 - 8ms/epoch - 3ms/step
# Epoch 108/150
# 3/3 - 0s - loss: 0.0332 - accuracy: 0.9932 - 7ms/epoch - 2ms/step
# Epoch 109/150
# 3/3 - 0s - loss: 0.0324 - accuracy: 0.9932 - 13ms/epoch - 4ms/step
# Epoch 110/150
# 3/3 - 0s - loss: 0.0316 - accuracy: 0.9932 - 4ms/epoch - 1ms/step
# Epoch 111/150
# 3/3 - 0s - loss: 0.0310 - accuracy: 0.9932 - 13ms/epoch - 4ms/step
# Epoch 112/150
# 3/3 - 0s - loss: 0.0303 - accuracy: 0.9932 - 0s/epoch - 0s/step
# Epoch 113/150
# 3/3 - 0s - loss: 0.0297 - accuracy: 0.9932 - 17ms/epoch - 6ms/step
# Epoch 114/150
# 3/3 - 0s - loss: 0.0291 - accuracy: 0.9932 - 5ms/epoch - 2ms/step
# Epoch 115/150
# 3/3 - 0s - loss: 0.0286 - accuracy: 0.9932 - 12ms/epoch - 4ms/step
# Epoch 116/150
# 3/3 - 0s - loss: 0.0280 - accuracy: 0.9932 - 13ms/epoch - 4ms/step
# Epoch 117/150
# 3/3 - 0s - loss: 0.0275 - accuracy: 0.9932 - 1ms/epoch - 405us/step
# Epoch 118/150
# 3/3 - 0s - loss: 0.0270 - accuracy: 0.9932 - 16ms/epoch - 5ms/step
# Epoch 119/150
# 3/3 - 0s - loss: 0.0266 - accuracy: 0.9932 - 6ms/epoch - 2ms/step
# Epoch 120/150
# 3/3 - 0s - loss: 0.0261 - accuracy: 0.9941 - 11ms/epoch - 4ms/step
# Epoch 121/150
# 3/3 - 0s - loss: 0.0257 - accuracy: 0.9941 - 14ms/epoch - 5ms/step
# Epoch 122/150
# 3/3 - 0s - loss: 0.0253 - accuracy: 0.9941 - 976us/epoch - 325us/step
# Epoch 123/150
# 3/3 - 0s - loss: 0.0248 - accuracy: 0.9941 - 16ms/epoch - 5ms/step
# Epoch 124/150
# 3/3 - 0s - loss: 0.0244 - accuracy: 0.9941 - 4ms/epoch - 1ms/step
# Epoch 125/150
# 3/3 - 0s - loss: 0.0241 - accuracy: 0.9941 - 13ms/epoch - 4ms/step
# Epoch 126/150
# 3/3 - 0s - loss: 0.0237 - accuracy: 0.9949 - 6ms/epoch - 2ms/step
# Epoch 127/150
# 3/3 - 0s - loss: 0.0233 - accuracy: 0.9949 - 3ms/epoch - 1ms/step
# Epoch 128/150
# 3/3 - 0s - loss: 0.0230 - accuracy: 0.9949 - 14ms/epoch - 5ms/step
# Epoch 129/150
# 3/3 - 0s - loss: 0.0226 - accuracy: 0.9949 - 0s/epoch - 0s/step
# Epoch 130/150
# 3/3 - 0s - loss: 0.0223 - accuracy: 0.9949 - 17ms/epoch - 6ms/step
# Epoch 131/150
# 3/3 - 0s - loss: 0.0220 - accuracy: 0.9949 - 7ms/epoch - 2ms/step
# Epoch 132/150
# 3/3 - 0s - loss: 0.0217 - accuracy: 0.9958 - 10ms/epoch - 3ms/step
# Epoch 133/150
# 3/3 - 0s - loss: 0.0214 - accuracy: 0.9958 - 14ms/epoch - 5ms/step
# Epoch 134/150
# 3/3 - 0s - loss: 0.0212 - accuracy: 0.9958 - 502us/epoch - 167us/step
# Epoch 135/150
# 3/3 - 0s - loss: 0.0209 - accuracy: 0.9958 - 17ms/epoch - 6ms/step
# Epoch 136/150
# 3/3 - 0s - loss: 0.0206 - accuracy: 0.9958 - 0s/epoch - 0s/step
# Epoch 137/150
# 3/3 - 0s - loss: 0.0203 - accuracy: 0.9958 - 18ms/epoch - 6ms/step
# Epoch 138/150
# 3/3 - 0s - loss: 0.0201 - accuracy: 0.9958 - 11ms/epoch - 4ms/step
# Epoch 139/150
# 3/3 - 0s - loss: 0.0198 - accuracy: 0.9958 - 3ms/epoch - 1ms/step
# Epoch 140/150
# 3/3 - 0s - loss: 0.0196 - accuracy: 0.9958 - 14ms/epoch - 5ms/step
# Epoch 141/150
# 3/3 - 0s - loss: 0.0194 - accuracy: 0.9958 - 0s/epoch - 0s/step
# Epoch 142/150
# 3/3 - 0s - loss: 0.0191 - accuracy: 0.9958 - 17ms/epoch - 6ms/step
# Epoch 143/150
# 3/3 - 0s - loss: 0.0189 - accuracy: 0.9958 - 0s/epoch - 0s/step
# Epoch 144/150
# 3/3 - 0s - loss: 0.0187 - accuracy: 0.9958 - 17ms/epoch - 6ms/step
# Epoch 145/150
# 3/3 - 0s - loss: 0.0185 - accuracy: 0.9958 - 12ms/epoch - 4ms/step
# Epoch 146/150
# 3/3 - 0s - loss: 0.0183 - accuracy: 0.9958 - 3ms/epoch - 933us/step
# Epoch 147/150
# 3/3 - 0s - loss: 0.0181 - accuracy: 0.9958 - 14ms/epoch - 5ms/step
# Epoch 148/150
# 3/3 - 0s - loss: 0.0179 - accuracy: 0.9958 - 0s/epoch - 0s/step
# Epoch 149/150
# 3/3 - 0s - loss: 0.0177 - accuracy: 0.9958 - 16ms/epoch - 5ms/step
# Epoch 150/150
# 3/3 - 0s - loss: 0.0176 - accuracy: 0.9958 - 3ms/epoch - 1ms/step

# %%
# Converting history into a DataFrame
history_df2 = pd.DataFrame(history.history)

# %%
# Extracting epochs
epochs = range(1, len(history_df2) + 1)

# Plotting Training Accuracy
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, history_df2['accuracy'], label='Training Accuracy', color='blue')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.suptitle("Model Training 3: Accuracy and Loss Over Epochs")

# Plotting Training Loss
plt.subplot(1, 2, 2)
plt.plot(epochs, history_df2['loss'], label='Training Loss', color='red')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
