# %%
import keras
from keras import layers
from keras.datasets import imdb
from keras.preprocessing import sequence

# Configuration adjustments for faster training
max_features = 2000  # Number of words to consider as features
max_len = 500  # Use a moderate sequence length
embedding_dim = 32  # Reduce embedding dimensionality
batch_size = 1024  # Increase batch size for faster epochs

# Load the IMDb data
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

# Preprocess the data
x_train = sequence.pad_sequences(x_train, maxlen=max_len)
x_test = sequence.pad_sequences(x_test, maxlen=max_len)

# Define the model with a 1D Convolutional layer followed by Global Average Pooling
model = keras.models.Sequential()
model.add(layers.Embedding(max_features, embedding_dim, input_length=max_len))
model.add(layers.Conv1D(16, 7, activation='relu'))
model.add(layers.GlobalAveragePooling1D())
model.add(layers.Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model with the adjusted configuration
history = model.fit(x_train, y_train,
                    epochs=30,  # Adjust the number of epochs as needed
                    batch_size=batch_size,
                    validation_split=0.3)
# Out:
# Epoch 1/30
# 18/18 [==============================] - 6s 300ms/step - loss: 0.6928 - accuracy: 0.5215 - val_loss: 0.6920 - val_accuracy: 0.5113
# Epoch 2/30
# 18/18 [==============================] - 5s 279ms/step - loss: 0.6905 - accuracy: 0.5741 - val_loss: 0.6878 - val_accuracy: 0.6759
# Epoch 3/30
# 18/18 [==============================] - 5s 282ms/step - loss: 0.6842 - accuracy: 0.6190 - val_loss: 0.6771 - val_accuracy: 0.6605
# Epoch 4/30
# 18/18 [==============================] - 5s 290ms/step - loss: 0.6699 - accuracy: 0.6663 - val_loss: 0.6572 - val_accuracy: 0.7152
# Epoch 5/30
# 18/18 [==============================] - 6s 325ms/step - loss: 0.6434 - accuracy: 0.7325 - val_loss: 0.6243 - val_accuracy: 0.7435
# Epoch 6/30
# 18/18 [==============================] - 5s 305ms/step - loss: 0.6060 - accuracy: 0.7642 - val_loss: 0.5825 - val_accuracy: 0.7727
# Epoch 7/30
# 18/18 [==============================] - 6s 309ms/step - loss: 0.5622 - accuracy: 0.7879 - val_loss: 0.5399 - val_accuracy: 0.7916
# Epoch 8/30
# 18/18 [==============================] - 6s 318ms/step - loss: 0.5176 - accuracy: 0.8104 - val_loss: 0.4995 - val_accuracy: 0.8144
# Epoch 9/30
# 18/18 [==============================] - 6s 317ms/step - loss: 0.4758 - accuracy: 0.8302 - val_loss: 0.4621 - val_accuracy: 0.8329
# Epoch 10/30
# 18/18 [==============================] - 5s 301ms/step - loss: 0.4392 - accuracy: 0.8461 - val_loss: 0.4330 - val_accuracy: 0.8392
# Epoch 11/30
# 18/18 [==============================] - 5s 288ms/step - loss: 0.4096 - accuracy: 0.8528 - val_loss: 0.4093 - val_accuracy: 0.8484
# Epoch 12/30
# 18/18 [==============================] - 5s 281ms/step - loss: 0.3878 - accuracy: 0.8585 - val_loss: 0.3932 - val_accuracy: 0.8523
# Epoch 13/30
# 18/18 [==============================] - 5s 287ms/step - loss: 0.3686 - accuracy: 0.8637 - val_loss: 0.3810 - val_accuracy: 0.8529
# Epoch 14/30
# 18/18 [==============================] - 5s 288ms/step - loss: 0.3539 - accuracy: 0.8671 - val_loss: 0.3685 - val_accuracy: 0.8612
# Epoch 15/30
# 18/18 [==============================] - 5s 289ms/step - loss: 0.3410 - accuracy: 0.8710 - val_loss: 0.3608 - val_accuracy: 0.8619
# Epoch 16/30
# 18/18 [==============================] - 5s 289ms/step - loss: 0.3313 - accuracy: 0.8743 - val_loss: 0.3537 - val_accuracy: 0.8637
# Epoch 17/30
# 18/18 [==============================] - 5s 287ms/step - loss: 0.3215 - accuracy: 0.8779 - val_loss: 0.3472 - val_accuracy: 0.8660
# Epoch 18/30
# 18/18 [==============================] - 5s 293ms/step - loss: 0.3132 - accuracy: 0.8803 - val_loss: 0.3424 - val_accuracy: 0.8677
# Epoch 19/30
# 18/18 [==============================] - 5s 296ms/step - loss: 0.3065 - accuracy: 0.8825 - val_loss: 0.3391 - val_accuracy: 0.8691
# Epoch 20/30
# 18/18 [==============================] - 5s 296ms/step - loss: 0.2996 - accuracy: 0.8850 - val_loss: 0.3348 - val_accuracy: 0.8708
# Epoch 21/30
# 18/18 [==============================] - 5s 301ms/step - loss: 0.2936 - accuracy: 0.8865 - val_loss: 0.3341 - val_accuracy: 0.8701
# Epoch 22/30
# 18/18 [==============================] - 5s 289ms/step - loss: 0.2898 - accuracy: 0.8874 - val_loss: 0.3303 - val_accuracy: 0.8721
# Epoch 23/30
# 18/18 [==============================] - 6s 315ms/step - loss: 0.2842 - accuracy: 0.8906 - val_loss: 0.3286 - val_accuracy: 0.8728
# Epoch 24/30
# 18/18 [==============================] - 6s 314ms/step - loss: 0.2801 - accuracy: 0.8909 - val_loss: 0.3342 - val_accuracy: 0.8676
# Epoch 25/30
# 18/18 [==============================] - 5s 284ms/step - loss: 0.2794 - accuracy: 0.8901 - val_loss: 0.3251 - val_accuracy: 0.8735
# Epoch 26/30
# 18/18 [==============================] - 4s 240ms/step - loss: 0.2740 - accuracy: 0.8922 - val_loss: 0.3246 - val_accuracy: 0.8713
# Epoch 27/30
# 18/18 [==============================] - 5s 253ms/step - loss: 0.2693 - accuracy: 0.8938 - val_loss: 0.3233 - val_accuracy: 0.8736
# Epoch 28/30
# 18/18 [==============================] - 5s 255ms/step - loss: 0.2662 - accuracy: 0.8962 - val_loss: 0.3225 - val_accuracy: 0.8740
# Epoch 29/30
# 18/18 [==============================] - 4s 232ms/step - loss: 0.2635 - accuracy: 0.8962 - val_loss: 0.3220 - val_accuracy: 0.8743
# Epoch 30/30
# 18/18 [==============================] - 4s 232ms/step - loss: 0.2605 - accuracy: 0.8988 - val_loss: 0.3236 - val_accuracy: 0.8739

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.datasets import imdb
from keras.preprocessing import sequence
from keras import layers
from keras.models import Sequential

# Converting history into a DataFrame
history_df = pd.DataFrame(history.history)

# Extracting epochs
epochs_range = np.array(range(1, len(history_df) + 1))

# Plot Training and Validation Accuracy
plt.figure(figsize=(14, 5))

# Plot training and validation accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs_range, history_df['accuracy'], label='Training Accuracy', color='blue')
plt.plot(epochs_range, history_df['val_accuracy'], label='Validation Accuracy', color='green')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, history_df['loss'], label='Training Loss', color='red')
plt.plot(epochs_range, history_df['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.suptitle("Model Training: Accuracy and Loss Over Epochs")
plt.tight_layout()
plt.show()
